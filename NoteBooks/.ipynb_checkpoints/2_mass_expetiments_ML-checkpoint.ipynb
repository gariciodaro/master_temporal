# %%
import os
import sys

sys.path.append("/home/gari/Desktop/master_tesis_v3/MLDiagnosisTool/")
sys.path.append("/home/gari/Desktop/master_tesis_v3/MLDiagnosisTool/Classes/")
sys.path.append("/home/gari/Desktop/master_tesis_v3/")

from OFHandlers import OFHandlers as OFH
import CoreML
import pandas as pd
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import SelectKBest, chi2
# Out:
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.bagging module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
#Machine learning metrics
from sklearn.metrics import (roc_auc_score,
                             recall_score,
                             f1_score,
                             average_precision_score,
                             accuracy_score,
                             balanced_accuracy_score,
                             roc_curve,
                             precision_score)

# %%
def run_experiment(experiment):
    #experiment="_entropy_delta_theta"
    data_co="/home/gari/Desktop/master_tesis_v3/Data/Datasets_"
    data_origin=data_co+experiment+"/prepared_train_data_set.file"
    
    data_test_path=data_co+experiment+"/prepared_test_data_set.file"


    note_exp=experiment

    data=OFH.load_object(data_origin)
    score_1=CoreML.core_diagnosis(data_origin=data,
                      data_origin_string="object_dataframe",
                      name="/eeg_"+experiment,
                      string_metric="roc_auc_score",
                      number_of_clusters=200,
                      hiper_tunning_iters=200,
                      futher_op_boo=True,
                      balance_train=False,
                      clustering=True,
                      polynomial=True,
                      test_size=0.2,
                      path_to_test=data_test_path,
                      note_exp=note_exp)
    print("EEG",score_1)

# %%
experiment="delta_theta_alpha_beta"

run_experiment(experiment)
# Out:
# categorical_columns Index([], dtype='object')
#             0         1         2         3         4         5         6  \
# 0    0.627754  0.122749  0.234170  0.015327  0.715801  0.126129  0.144320
# 1    0.529713  0.159418  0.294946  0.015923  0.582295  0.166608  0.236047
# 2    0.640706  0.136189  0.208363  0.014743  0.707069  0.142156  0.138201
# 3    0.552255  0.137244  0.296971  0.013530  0.619201  0.155509  0.210825
# 4    0.613892  0.105211  0.269537  0.011359  0.671494  0.110627  0.206124
# ..        ...       ...       ...       ...       ...       ...       ...
# 990  0.819297  0.085033  0.080440  0.015230  0.524557  0.237771  0.200857
# 991  0.796659  0.105218  0.086142  0.011981  0.554462  0.259012  0.156074
# 992  0.777571  0.100480  0.098815  0.023134  0.520538  0.238764  0.196234
# 993  0.822560  0.075538  0.085279  0.016623  0.558455  0.220915  0.175021
# 994  0.797555  0.084799  0.104368  0.013279  0.513850  0.239835  0.208606
#
#             7         8         9  ...        35        36        37  \
# 0    0.013749  0.715463  0.147645  ...  0.016681  0.804198  0.099034
# 1    0.015051  0.628368  0.155677  ...  0.008494  0.868649  0.060911
# 2    0.012575  0.803168  0.094484  ...  0.014323  0.901057  0.052849
# 3    0.014464  0.685784  0.151074  ...  0.010711  0.818824  0.092361
# 4    0.011755  0.728677  0.120378  ...  0.013026  0.846586  0.085080
# ..        ...       ...       ...  ...       ...       ...       ...
# 990  0.036816  0.870439  0.074551  ...  0.010834  0.821600  0.100695
# 991  0.030452  0.847354  0.099802  ...  0.008601  0.771376  0.160651
# 992  0.044464  0.802598  0.111927  ...  0.016997  0.801935  0.134175
# 993  0.045609  0.845910  0.086505  ...  0.012706  0.782023  0.132555
# 994  0.037708  0.857235  0.069585  ...  0.009879  0.803222  0.104243
#
#            38        39        40        41        42        43   44
# 0    0.084440  0.012328  0.828228  0.081324  0.073478  0.016970  1.0
# 1    0.063539  0.006901  0.734441  0.136422  0.111755  0.017382  1.0
# 2    0.039589  0.006505  0.780116  0.135600  0.067876  0.016407  1.0
# 3    0.080074  0.008741  0.737871  0.113327  0.123733  0.025070  1.0
# 4    0.059288  0.009046  0.774613  0.113857  0.094707  0.016823  1.0
# ..        ...       ...       ...       ...       ...       ...  ...
# 990  0.060701  0.017004  0.897422  0.052363  0.039326  0.010890  1.0
# 991  0.047895  0.020078  0.888037  0.071815  0.027929  0.012218  1.0
# 992  0.040374  0.023517  0.847775  0.094370  0.036530  0.021325  1.0
# 993  0.059507  0.025915  0.883848  0.066292  0.035256  0.014605  1.0
# 994  0.064930  0.027605  0.892863  0.056314  0.035761  0.015062  1.0
#
# [995 rows x 45 columns]
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# Categorical data not detected.
# models ['RF', 'XGB']
# scores [0.5326750700280112, 0.5042857142857142]
# max_mean_cv_validation for no-clustering no-polynomial 0.5326750700280112
# models ['RF', 'XGB']
# scores [0.5398739495798319, 0.5088515406162465]
# max_mean_cv_validation for clustering 0.5398739495798319
# models ['RF', 'XGB']
# scores [0.49491596638655455, 0.48200280112044813]
# max_mean_cv_validation for for polynomial 0.49491596638655455
# score_mean_dict {0: 0.5326750700280112, 1: 0.5398739495798319, 2: 0.49491596638655455}
# temp_dic {'RF': 0.5398739495798319, 'XGB': 0.5088515406162465}
# selected second:  XGB 0.5088515406162465
# Starting hiper parameters tunning...
# hiper tunning results on RF
#       index name_model validation score  \
# 0      116         RF         0.567115
# 1       38         RF         0.564566
# 2      132         RF         0.555476
# 3      102         RF         0.553824
# 4        4         RF         0.552731
# ..     ...        ...              ...
# 195    198         RF          0.48993
# 196     82         RF         0.488529
# 197    103         RF         0.487801
# 198    194         RF         0.474902
# 199     87         RF         0.470812
#
#                                                 params iteration
# 0    {'n_estimators': 4, 'random_state': 42, 'max_f...       116
# 1    {'n_estimators': 6, 'random_state': 0, 'max_fe...        38
# 2    {'n_estimators': 1, 'random_state': 42, 'max_f...       132
# 3    {'n_estimators': 50, 'random_state': 10, 'max_...       102
# 4    {'n_estimators': 11, 'random_state': 0, 'max_f...         4
# ..                                                 ...       ...
# 195  {'n_estimators': 14, 'random_state': 10, 'max_...       198
# 196  {'n_estimators': 2, 'random_state': 42, 'max_f...        82
# 197  {'n_estimators': 1, 'random_state': 10, 'max_f...       103
# 198  {'n_estimators': 1, 'random_state': 10, 'max_f...       194
# 199  {'n_estimators': 2, 'random_state': 0, 'max_fe...        87
#
# [200 rows x 5 columns]
# hiper tunning results on XGB
#       index name_model validation score  \
# 0       66        XGB         0.561022
# 1      169        XGB         0.558669
# 2      147        XGB         0.558627
# 3      127        XGB         0.556583
# 4      176        XGB         0.556443
# ..     ...        ...              ...
# 195    167        XGB         0.499468
# 196    188        XGB         0.499454
# 197    140        XGB         0.499202
# 198     64        XGB         0.497339
# 199    158        XGB          0.49598
#
#                                                 params iteration
# 0    {'min_child_weight': 1, 'max_depth': 7, 'learn...        66
# 1    {'min_child_weight': 1, 'max_depth': 7, 'learn...       169
# 2    {'min_child_weight': 1, 'max_depth': 3, 'learn...       147
# 3    {'min_child_weight': 1, 'max_depth': 10, 'lear...       127
# 4    {'min_child_weight': 1, 'max_depth': 3, 'learn...       176
# ..                                                 ...       ...
# 195  {'min_child_weight': 1, 'max_depth': 3, 'learn...       167
# 196  {'min_child_weight': 1, 'max_depth': 3, 'learn...       188
# 197  {'min_child_weight': 1, 'max_depth': 3, 'learn...       140
# 198  {'min_child_weight': 1, 'max_depth': 9, 'learn...        64
# 199  {'min_child_weight': 1, 'max_depth': 9, 'learn...       158
#
# [200 rows x 5 columns]
# before walking around hyperparameters
# RF 0.5671148459383752
# XGB 0.5610224089635855
# first futher op
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 4
# new score: 0.5671148459383752
# old score 0.5671148459383752
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 26
# new score: 0.5671148459383752
# old score 0.5671148459383752
# walking around  min_samples_split
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_split 10
# new score: 0.5671148459383752
# old score 0.5671148459383752
# walking around  min_samples_leaf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_leaf 2
# new score: 0.5671148459383752
# old score 0.5671148459383752
# walking around  bootstrap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters bootstrap 0
# new score: 0.5671148459383752
# old score 0.5671148459383752
# second futher op
# walking around  min_child_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_child_weight 1
# new score: 0.5610224089635855
# old score 0.5610224089635855
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 7
# new score: 0.5610224089635855
# old score 0.5610224089635855
# walking around  learning_rate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters learning_rate 0.27
# new score: 0.5681512605042016
# old score 0.5610224089635855
# walking around  reg_alpha
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_alpha 0.00375
# new score: 0.5681932773109243
# old score 0.5681512605042016
# walking around  reg_lambda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_lambda 1
# new score: 0.5681932773109243
# old score 0.5681932773109243
# walking around  gamma
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters gamma 0.056249999999999994
# new score: 0.562170868347339
# old score 0.5681932773109243
# walking around  subsample
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters subsample 0.8999999999999999
# new score: 0.5504761904761905
# old score 0.5681932773109243
# walking around  colsample_bytree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters colsample_bytree 0.5249999999999999
# new score: 0.5526890756302523
# old score 0.5681932773109243
# walking around  scale_pos_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters scale_pos_weight 1
# new score: 0.5681932773109243
# old score 0.5681932773109243
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 476
# new score: 0.5753501400560224
# old score 0.5681932773109243
# calculating candidates on test set:
# 1. best tunned model based on cv validation
# 2. best tunned model based on minimun std
# 3. first model (with default parameters)
# 4. second model (with default parameters)
# expected_score_1,expected_score_2 0.5533333333333333 0.5
# expected_score_3,expected_score_4 0.5266666666666666 0.5533333333333333
# results_on_test_dict {1: 0.5533333333333333, 2: 0.5, 3: 0.5266666666666666, 4: 0.5533333333333333}
# selected_key 1
# l [{'n_estimators': 4, 'random_state': 42, 'max_features': 'sqrt', 'max_depth': 33, 'min_samples_split': 10, 'min_samples_leaf': 2, 'bootstrap': False}, 0.9798459383753501, 0.5533333333333333, 'RF', 0.0]
# saving scaler at /home/gari/Desktop/master_tesis_v3/MLDiagnosisTool/eeg_delta_theta_alpha_beta/eeg_delta_theta_alpha_beta_scaler.file
0
# ..        ...       ...       ...       ...       ...       ...  ...
# 990  0.821600  0.100695  0.060701  0.897422  0.052363  0.039326  1.0
# 991  0.771376  0.160651  0.047895  0.888037  0.071815  0.027929  1.0
# 992  0.801935  0.134175  0.040374  0.847775  0.094370  0.036530  1.0
# 993  0.782023  0.132555  0.059507  0.883848  0.066292  0.035256  1.0
# 994  0.803222  0.104243  0.064930  0.892863  0.056314  0.035761  1.0
#
# [995 rows x 34 columns]
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# Categorical data not detected.
# models ['RF', 'XGB']
# scores [0.5066806722689076, 0.5456722689075629]
# max_mean_cv_validation for no-clustering no-polynomial 0.5456722689075629
# models ['RF', 'XGB']
# scores [0.5279551820728291, 0.5065266106442576]
# max_mean_cv_validation for clustering 0.5279551820728291
# models ['RF', 'XGB']
# scores [0.49950980392156863, 0.4510084033613445]
# max_mean_cv_validation for for polynomial 0.49950980392156863
# score_mean_dict {0: 0.5456722689075629, 1: 0.5279551820728291, 2: 0.49950980392156863}
# temp_dic {'RF': 0.5066806722689076, 'XGB': 0.5456722689075629}
# selected second:  RF 0.5066806722689076
# Starting hiper parameters tunning...
# hiper tunning results on XGB
#       index name_model validation score  \
# 0       36        XGB         0.562521
# 1       67        XGB         0.561148
# 2      121        XGB         0.550504
# 3      131        XGB          0.55021
# 4       43        XGB         0.549216
# ..     ...        ...              ...
# 195    107        XGB         0.480728
# 196    187        XGB         0.480518
# 197     74        XGB         0.479482
# 198    195        XGB         0.477913
# 199    163        XGB         0.471092
#
#                                                 params iteration
# 0    {'min_child_weight': 1, 'max_depth': 7, 'learn...        36
# 1    {'min_child_weight': 1, 'max_depth': 3, 'learn...        67
# 2    {'min_child_weight': 1, 'max_depth': 3, 'learn...       121
# 3    {'min_child_weight': 1, 'max_depth': 10, 'lear...       131
# 4    {'min_child_weight': 1, 'max_depth': 7, 'learn...        43
# ..                                                 ...       ...
# 195  {'min_child_weight': 1, 'max_depth': 9, 'learn...       107
# 196  {'min_child_weight': 1, 'max_depth': 9, 'learn...       187
# 197  {'min_child_weight': 1, 'max_depth': 3, 'learn...        74
# 198  {'min_child_weight': 1, 'max_depth': 3, 'learn...       195
# 199  {'min_child_weight': 1, 'max_depth': 3, 'learn...       163
#
# [200 rows x 5 columns]
# hiper tunning results on RF
#       index name_model validation score  \
# 0       30         RF         0.561092
# 1      139         RF         0.557479
# 2       49         RF         0.554048
# 3      120         RF         0.551765
# 4      183         RF         0.550518
# ..     ...        ...              ...
# 195    134         RF         0.482899
# 196    197         RF         0.479412
# 197     56         RF         0.467857
# 198    165         RF         0.461933
# 199    174         RF         0.448557
#
#                                                 params iteration
# 0    {'n_estimators': 1, 'random_state': 0, 'max_fe...        30
# 1    {'n_estimators': 26, 'random_state': 10, 'max_...       139
# 2    {'n_estimators': 19, 'random_state': 0, 'max_f...        49
# 3    {'n_estimators': 16, 'random_state': 13, 'max_...       120
# 4    {'n_estimators': 50, 'random_state': 0, 'max_f...       183
# ..                                                 ...       ...
# 195  {'n_estimators': 26, 'random_state': 42, 'max_...       134
# 196  {'n_estimators': 1, 'random_state': 10, 'max_f...       197
# 197  {'n_estimators': 1, 'random_state': 13, 'max_f...        56
# 198  {'n_estimators': 2, 'random_state': 10, 'max_f...       165
# 199  {'n_estimators': 1, 'random_state': 10, 'max_f...       174
#
# [200 rows x 5 columns]
# before walking around hyperparameters
# XGB 0.5625210084033613
# RF 0.5610924369747898
# first futher op
# walking around  min_child_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_child_weight 1
# new score: 0.5625210084033613
# old score 0.5625210084033613
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 7
# new score: 0.5625210084033613
# old score 0.5625210084033613
# walking around  learning_rate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters learning_rate 0.6000000000000001
# new score: 0.5279831932773109
# old score 0.5625210084033613
# walking around  reg_alpha
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_alpha 0.0975
# new score: 0.5516666666666666
# old score 0.5625210084033613
# walking around  reg_lambda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_lambda 0.0
# new score: 0.5411064425770309
# old score 0.5625210084033613
# walking around  gamma
# candidate update hiperparameters gamma 0.00075
# new score: 0.5706302521008404
# old score 0.5625210084033613
# walking around  subsample
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters subsample 0.75
# new score: 0.5172829131652661
# old score 0.5706302521008404
# walking around  colsample_bytree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters colsample_bytree 0.75
# new score: 0.5385994397759103
# old score 0.5706302521008404
# walking around  scale_pos_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters scale_pos_weight 1
# new score: 0.5706302521008404
# old score 0.5706302521008404
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 312
# new score: 0.57296918767507
# old score 0.5706302521008404
# second futher op
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 1
# new score: 0.5610924369747898
# old score 0.5610924369747898
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 33
# new score: 0.5610924369747898
# old score 0.5610924369747898
# walking around  min_samples_split
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_split 5
# new score: 0.5610924369747898
# old score 0.5610924369747898
# walking around  min_samples_leaf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_leaf 2
# new score: 0.5610924369747898
# old score 0.5610924369747898
# walking around  bootstrap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters bootstrap 0
# new score: 0.5610924369747898
# old score 0.5610924369747898
# calculating candidates on test set:
# 1. best tunned model based on cv validation
# 2. best tunned model based on minimun std
# 3. first model (with default parameters)
# 4. second model (with default parameters)
# expected_score_1,expected_score_2 0.42 0.5333333333333333
# expected_score_3,expected_score_4 0.45333333333333337 0.4466666666666666
# results_on_test_dict {1: 0.42, 2: 0.5333333333333333, 3: 0.45333333333333337, 4: 0.4466666666666666}
# selected_key 2
# l [{'n_estimators': 1, 'random_state': 0, 'max_features': 'auto', 'max_depth': 43, 'min_samples_split': 5, 'min_samples_leaf': 2, 'bootstrap': False}, 0.949299719887955, 0.5333333333333333, 'RF', 0.0]
# saving scaler at /home/gari/Desktop/master_tesis_v3/MLDiagnosisTool/eeg_delta_theta_alpha/eeg_delta_theta_alpha_scaler.file
# Raw accuracy 0.48364485981308414
# accuracy 0.5697674418604651
# f1_score 0.6942148760330579
# recall 0.6086956521739131
# precision 0.8076923076923077
# selected_model: RF
# selected parameters: {'n_estimators': 1, 'random_state': 0, 'max_features': 'auto', 'max_depth': 43, 'min_samples_split': 5, 'min_samples_leaf': 2, 'bootstrap': False}
# score on test set of data: 0.5333333333333333
# Do not forget to see your report in: /home/gari/Desktop/master_tesis_v3/MLDiagnosisTool/eeg_delta_theta_alpha
# --- 755.7803280353546 seconds ---
# EEG 0.5333333333333333

# %%
#experiment="delta_theta_alpha_entropy"

#run_experiment(experiment)

# %%
experiment="delta_theta"

run_experiment(experiment)
# Out:
# categorical_columns Index([], dtype='object')
# temp_dic {'RF': 0.5432773109243698, 'XGB': 0.531358543417367}
# selected second:  XGB 0.531358543417367
# Starting hiper parameters tunning...
# hiper tunning results on RF
#       index name_model validation score  \
# 0      182         RF          0.57028
# 1      160         RF         0.553852
# 2      180         RF         0.552759
# 3      169         RF         0.551639
# 4       26         RF         0.551625
# ..     ...        ...              ...
# 195     86         RF         0.503235
# 196     18         RF              0.5
# 197    167         RF         0.495994
# 198    174         RF         0.492521
# 199     92         RF         0.473852
#
#                                                 params iteration
# 0    {'n_estimators': 12, 'random_state': 13, 'max_...       182
# 1    {'n_estimators': 24, 'random_state': 13, 'max_...       160
# 2    {'n_estimators': 17, 'random_state': 13, 'max_...       180
# 3    {'n_estimators': 9, 'random_state': 10, 'max_f...       169
# 4    {'n_estimators': 33, 'random_state': 0, 'max_f...        26
# ..                                                 ...       ...
# 195  {'n_estimators': 1, 'random_state': 13, 'max_f...        86
# 196  {'n_estimators': 2, 'random_state': 10, 'max_f...        18
# 197  {'n_estimators': 7, 'random_state': 42, 'max_f...       167
# 198  {'n_estimators': 16, 'random_state': 0, 'max_f...       174
# 199  {'n_estimators': 1, 'random_state': 0, 'max_fe...        92
#
# [200 rows x 5 columns]
# hiper tunning results on XGB
#       index name_model validation score  \
# 0       44        XGB         0.566891
# 1      101        XGB         0.565756
# 2      179        XGB          0.56465
# 3      114        XGB         0.563431
# 4       28        XGB         0.562213
# ..     ...        ...              ...
# 195    156        XGB         0.499034
# 196     97        XGB         0.496905
# 197    191        XGB         0.493389
# 198    174        XGB         0.492493
# 199     57        XGB          0.48402
#
#                                                 params iteration
# 0    {'min_child_weight': 1, 'max_depth': 3, 'learn...        44
# 1    {'min_child_weight': 1, 'max_depth': 7, 'learn...       101
# 2    {'min_child_weight': 1, 'max_depth': 3, 'learn...       179
# 3    {'min_child_weight': 1, 'max_depth': 9, 'learn...       114
# 4    {'min_child_weight': 1, 'max_depth': 9, 'learn...        28
# ..                                                 ...       ...
# 195  {'min_child_weight': 1, 'max_depth': 3, 'learn...       156
# 196  {'min_child_weight': 1, 'max_depth': 3, 'learn...        97
# 197  {'min_child_weight': 1, 'max_depth': 3, 'learn...       191
# 198  {'min_child_weight': 1, 'max_depth': 9, 'learn...       174
# 199  {'min_child_weight': 1, 'max_depth': 3, 'learn...        57
#
# [200 rows x 5 columns]
# before walking around hyperparameters
# RF 0.570280112044818
# XGB 0.5668907563025211
# first futher op
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 12
# new score: 0.570280112044818
# old score 0.570280112044818
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 11
# new score: 0.570280112044818
# old score 0.570280112044818
# walking around  min_samples_split
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_split 10
# new score: 0.570280112044818
# old score 0.570280112044818
# walking around  min_samples_leaf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_leaf 2
# new score: 0.570280112044818
# old score 0.570280112044818
# walking around  bootstrap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters bootstrap 0
# new score: 0.570280112044818
# old score 0.570280112044818
# second futher op
# walking around  min_child_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_child_weight 1
# new score: 0.5668907563025211
# old score 0.5668907563025211
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 3
# new score: 0.5668907563025211
# old score 0.5668907563025211
# walking around  learning_rate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters learning_rate 0.33749999999999997
# new score: 0.5753081232492997
# old score 0.5668907563025211
# walking around  reg_alpha
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_alpha 0.00375
# new score: 0.5658263305322129
# old score 0.5753081232492997
# walking around  reg_lambda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_lambda 3.0375
# new score: 0.5587114845938375
# old score 0.5753081232492997
# walking around  gamma
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters gamma 0.03375
# new score: 0.577703081232493
# old score 0.5753081232492997
# walking around  subsample
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters subsample 0.75
# new score: 0.5504201680672269
# old score 0.577703081232493
# walking around  colsample_bytree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters colsample_bytree 0.0
# new score: 0.5574649859943978
# old score 0.577703081232493
# walking around  scale_pos_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters scale_pos_weight 1
# new score: 0.577703081232493
# old score 0.577703081232493
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 192
# new score: 0.5777170868347339
# old score 0.577703081232493
# calculating candidates on test set:
# 1. best tunned model based on cv validation
# 2. best tunned model based on minimun std
# 3. first model (with default parameters)
# 4. second model (with default parameters)
# expected_score_1,expected_score_2 0.4666666666666667 0.5
# expected_score_3,expected_score_4 0.39999999999999997 0.5066666666666666
# results_on_test_dict {1: 0.4666666666666667, 2: 0.5, 3: 0.39999999999999997, 4: 0.5066666666666666}
# selected_key 4
# l [None, 0.9513585434173669, 0.5066666666666666, 'XGB', None]
# saving scaler at /home/gari/Desktop/master_tesis_v3/MLDiagnosisTool/eeg_delta_theta/eeg_delta_theta_scaler.file
# Raw accuracy 0.5771028037383178
# accuracy 0.627906976744186
# f1_score 0.7333333333333333
# recall 0.6376811594202898
# precision 0.8627450980392157
# selected_model: XGB
# selected parameters: None
# score on test set of data: 0.5066666666666666
# Do not forget to see your report in: /home/gari/Desktop/master_tesis_v3/MLDiagnosisTool/eeg_delta_theta
# --- 1362.0323791503906 seconds ---
# EEG 0.5066666666666666

# %%
experiment="delta"

run_experiment(experiment)
# Out:
# categorical_columns Index([], dtype='object')
#             0         1         2         3         4         5         6  \
# 0    0.627754  0.715801  0.715463  0.544394  0.588347  0.855764  0.797655
# 1    0.529713  0.582295  0.628368  0.555450  0.564254  0.853851  0.817534
# 2    0.640706  0.707069  0.803168  0.646831  0.617718  0.836961  0.791769
# 3    0.552255  0.619201  0.685784  0.544771  0.589083  0.867576  0.840309
# 4    0.613892  0.671494  0.728677  0.612205  0.635567  0.830275  0.807438
# ..        ...       ...       ...       ...       ...       ...       ...
# 990  0.819297  0.524557  0.870439  0.618100  0.920295  0.632934  0.546350
# 991  0.796659  0.554462  0.847354  0.629446  0.905800  0.649560  0.598689
# 992  0.777571  0.520538  0.802598  0.620347  0.902717  0.706268  0.545362
# 993  0.822560  0.558455  0.845910  0.664436  0.931248  0.624716  0.591228
# 994  0.797555  0.513850  0.857235  0.626394  0.913888  0.583243  0.540274
#
#             7         8         9        10   11
# 0    0.725947  0.729926  0.804198  0.828228  1.0
# 1    0.800997  0.749063  0.868649  0.734441  1.0
# 2    0.834161  0.676511  0.901057  0.780116  1.0
# 3    0.798811  0.748853  0.818824  0.737871  1.0
# 4    0.751714  0.691697  0.846586  0.774613  1.0
# ..        ...       ...       ...       ...  ...
# 990  0.952418  0.871842  0.821600  0.897422  1.0
# 991  0.943623  0.880653  0.771376  0.888037  1.0
# 992  0.921963  0.866143  0.801935  0.847775  1.0
# 993  0.948241  0.905555  0.782023  0.883848  1.0
# 994  0.935092  0.886268  0.803222  0.892863  1.0
#
# [995 rows x 12 columns]
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# Categorical data not detected.
# models ['RF', 'XGB']
# scores [0.5148879551820729, 0.5395798319327731]
# max_mean_cv_validation for no-clustering no-polynomial 0.5395798319327731
# models ['RF', 'XGB']
# scores [0.5173949579831933, 0.5325490196078432]
# max_mean_cv_validation for clustering 0.5325490196078432
# models ['RF', 'XGB']
# scores [0.5256442577030812, 0.5219047619047619]
# max_mean_cv_validation for for polynomial 0.5256442577030812
# score_mean_dict {0: 0.5395798319327731, 1: 0.5325490196078432, 2: 0.5256442577030812}
# temp_dic {'RF': 0.5148879551820729, 'XGB': 0.5395798319327731}
# selected second:  RF 0.5148879551820729
# Starting hiper parameters tunning...
# hiper tunning results on XGB
#       index name_model validation score  \
# 0       55        XGB         0.575168
# 1      133        XGB         0.574146
# 2      111        XGB         0.568123
# 3       50        XGB         0.562213
# 4      116        XGB          0.56119
# ..     ...        ...              ...
# 195    123        XGB         0.496863
# 196    185        XGB         0.493473
# 197    187        XGB         0.492017
# 198      8        XGB         0.483866
# 199    160        XGB         0.475882
#
#                                                 params iteration
# 0    {'min_child_weight': 1, 'max_depth': 9, 'learn...        55
# 1    {'min_child_weight': 1, 'max_depth': 7, 'learn...       133
# 2    {'min_child_weight': 1, 'max_depth': 10, 'lear...       111
# 3    {'min_child_weight': 1, 'max_depth': 3, 'learn...        50
# 4    {'min_child_weight': 1, 'max_depth': 9, 'learn...       116
# ..                                                 ...       ...
# 195  {'min_child_weight': 1, 'max_depth': 3, 'learn...       123
# 196  {'min_child_weight': 1, 'max_depth': 3, 'learn...       185
# 197  {'min_child_weight': 1, 'max_depth': 7, 'learn...       187
# 198  {'min_child_weight': 1, 'max_depth': 3, 'learn...         8
# 199  {'min_child_weight': 1, 'max_depth': 3, 'learn...       160
#
# [200 rows x 5 columns]
# hiper tunning results on RF
#       index name_model validation score  \
# 0      157         RF          0.56479
# 1       19         RF         0.555462
# 2      125         RF         0.551387
# 3       16         RF         0.549314
# 4      147         RF          0.54916
# ..     ...        ...              ...
# 195    169         RF          0.48895
# 196    199         RF         0.486611
# 197    162         RF         0.486401
# 198     61         RF         0.484426
# 199    124         RF         0.482129
#
#                                                 params iteration
# 0    {'n_estimators': 11, 'random_state': 10, 'max_...       157
# 1    {'n_estimators': 4, 'random_state': 10, 'max_f...        19
# 2    {'n_estimators': 4, 'random_state': 0, 'max_fe...       125
# 3    {'n_estimators': 2, 'random_state': 42, 'max_f...        16
# 4    {'n_estimators': 29, 'random_state': 10, 'max_...       147
# ..                                                 ...       ...
# 195  {'n_estimators': 17, 'random_state': 13, 'max_...       169
# 196  {'n_estimators': 9, 'random_state': 0, 'max_fe...       199
# 197  {'n_estimators': 48, 'random_state': 42, 'max_...       162
# 198  {'n_estimators': 1, 'random_state': 42, 'max_f...        61
# 199  {'n_estimators': 1, 'random_state': 13, 'max_f...       124
#
# [200 rows x 5 columns]
# before walking around hyperparameters
# XGB 0.5751680672268907
# RF 0.5647899159663865
# first futher op
# walking around  min_child_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_child_weight 1
# new score: 0.5751680672268907
# old score 0.5751680672268907
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 9
# new score: 0.5751680672268907
# old score 0.5751680672268907
# walking around  learning_rate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters learning_rate 0.33749999999999997
# new score: 0.555140056022409
# old score 0.5751680672268907
# walking around  reg_alpha
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_alpha 0.5625
# new score: 0.5562885154061625
# old score 0.5751680672268907
# walking around  reg_lambda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_lambda 1
# new score: 0.5751680672268907
# old score 0.5751680672268907
# walking around  gamma
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters gamma 0.0022500000000000003
# new score: 0.5751680672268907
# old score 0.5751680672268907
# walking around  subsample
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters subsample 0.75
# new score: 0.5254341736694677
# old score 0.5751680672268907
# walking around  colsample_bytree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters colsample_bytree 0.5625
# new score: 0.5431932773109244
# old score 0.5751680672268907
# walking around  scale_pos_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters scale_pos_weight 1
# new score: 0.5751680672268907
# old score 0.5751680672268907
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 45
# new score: 0.5906302521008403
# old score 0.5751680672268907
# second futher op
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 7
# new score: 0.5812885154061626
# old score 0.5647899159663865
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 22
# new score: 0.5812885154061626
# old score 0.5812885154061626
# walking around  min_samples_split
# candidate update hiperparameters min_samples_split 5
# new score: 0.5812885154061626
# old score 0.5812885154061626
# walking around  min_samples_leaf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_leaf 1
# new score: 0.5812885154061626
# old score 0.5812885154061626
# walking around  bootstrap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters bootstrap -9
# new score: 0.5812885154061626
# old score 0.5812885154061626
# calculating candidates on test set:
# 1. best tunned model based on cv validation
# 2. best tunned model based on minimun std
# 3. first model (with default parameters)
# 4. second model (with default parameters)
# expected_score_1,expected_score_2 0.52 0.49333333333333335
# expected_score_3,expected_score_4 0.4666666666666667 0.4466666666666666
# results_on_test_dict {1: 0.52, 2: 0.49333333333333335, 3: 0.4666666666666667, 4: 0.4466666666666666}
# selected_key 1
# l [{'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.3, 'reg_alpha': 0.3, 'reg_lambda': 1, 'gamma': 0.002, 'subsample': 1.0, 'colsample_bytree': 0.5, 'objective': 'binary:logistic', 'nthread': -1, 'scale_pos_weight': 1, 'seed': 10, 'n_estimators': 45}, 1.0, 0.52, 'XGB', 1.546218487394957]
# saving scaler at /home/gari/Desktop/master_tesis_v3/MLDiagnosisTool/eeg_delta/eeg_delta_scaler.file
# Raw accuracy 0.5397196261682243
# accuracy 0.5930232558139535
# f1_score 0.7058823529411766
# recall 0.6086956521739131
# precision 0.84
# selected_model: XGB
# selected parameters: {'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.3, 'reg_alpha': 0.3, 'reg_lambda': 1, 'gamma': 0.002, 'subsample': 1.0, 'colsample_bytree': 0.5, 'objective': 'binary:logistic', 'nthread': -1, 'scale_pos_weight': 1, 'seed': 10, 'n_estimators': 45}
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# Categorical data not detected.
# models ['RF', 'XGB']
# scores [0.47336134453781514, 0.44624649859943977]
# max_mean_cv_validation for no-clustering no-polynomial 0.47336134453781514
# models ['RF', 'XGB']
# scores [0.4214145658263305, 0.43315126050420166]
# max_mean_cv_validation for clustering 0.43315126050420166
# models ['RF', 'XGB']
# scores [0.5019187675070028, 0.4641316526610644]
# max_mean_cv_validation for for polynomial 0.5019187675070028
# score_mean_dict {0: 0.47336134453781514, 1: 0.43315126050420166, 2: 0.5019187675070028}
# temp_dic {'RF': 0.5019187675070028, 'XGB': 0.4641316526610644}
# selected second:  XGB 0.4641316526610644
# Starting hiper parameters tunning...
# hiper tunning results on RF
#       index name_model validation score  \
# 0       76         RF          0.53465
# 1        4         RF         0.526653
# 2       73         RF         0.519482
# 3       14         RF         0.518431
# 4      162         RF         0.517451
# ..     ...        ...              ...
# 195    108         RF         0.454566
# 196    192         RF         0.453459
# 197      8         RF         0.452311
# 198     78         RF         0.451022
# 199    102         RF         0.449832
#
#                                                 params iteration
# 0    {'n_estimators': 4, 'random_state': 10, 'max_f...        76
# 1    {'n_estimators': 2, 'random_state': 10, 'max_f...         4
# 2    {'n_estimators': 7, 'random_state': 10, 'max_f...        73
# 3    {'n_estimators': 9, 'random_state': 13, 'max_f...        14
# 4    {'n_estimators': 19, 'random_state': 13, 'max_...       162
# ..                                                 ...       ...
# 195  {'n_estimators': 41, 'random_state': 13, 'max_...       108
# 196  {'n_estimators': 19, 'random_state': 13, 'max_...       192
# 197  {'n_estimators': 21, 'random_state': 42, 'max_...         8
# 198  {'n_estimators': 28, 'random_state': 13, 'max_...        78
# 199  {'n_estimators': 12, 'random_state': 0, 'max_f...       102
#
# [200 rows x 5 columns]
# hiper tunning results on XGB
#       index name_model validation score  \
# 0       20        XGB         0.525546
# 1       43        XGB         0.519608
# 2      120        XGB         0.516218
# 3        8        XGB         0.513964
# 4        2        XGB         0.513473
# ..     ...        ...              ...
# 195     27        XGB         0.462801
# 196    136        XGB         0.460476
# 197    148        XGB         0.455994
# 198    194        XGB         0.454748
# 199    107        XGB         0.448754
#
#                                                 params iteration
# 0    {'min_child_weight': 1, 'max_depth': 3, 'learn...        20
# 1    {'min_child_weight': 1, 'max_depth': 9, 'learn...        43
# 2    {'min_child_weight': 1, 'max_depth': 9, 'learn...       120
# 3    {'min_child_weight': 1, 'max_depth': 10, 'lear...         8
# 4    {'min_child_weight': 1, 'max_depth': 7, 'learn...         2
# ..                                                 ...       ...
# 195  {'min_child_weight': 1, 'max_depth': 3, 'learn...        27
# 196  {'min_child_weight': 1, 'max_depth': 9, 'learn...       136
# 197  {'min_child_weight': 1, 'max_depth': 3, 'learn...       148
# 198  {'min_child_weight': 1, 'max_depth': 3, 'learn...       194
# 199  {'min_child_weight': 1, 'max_depth': 3, 'learn...       107
#
# [200 rows x 5 columns]
# before walking around hyperparameters
# RF 0.5346498599439776
# XGB 0.5255462184873949
# first futher op
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 4
# new score: 0.5346498599439776
# old score 0.5346498599439776
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 25
# new score: 0.5417507002801121
# old score 0.5346498599439776
# walking around  min_samples_split
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_split 2
# new score: 0.5417507002801121
# old score 0.5417507002801121
# walking around  min_samples_leaf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_leaf 1
# new score: 0.5417507002801121
# old score 0.5417507002801121
# walking around  bootstrap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters bootstrap 0
# new score: 0.5417507002801121
# old score 0.5417507002801121
# second futher op
# walking around  min_child_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_child_weight 0
# new score: 0.5302380952380952
# old score 0.5255462184873949
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 3
# new score: 0.5302380952380952
# old score 0.5302380952380952
# walking around  learning_rate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters learning_rate 0.6000000000000001
# new score: 0.543249299719888
# old score 0.5302380952380952
# walking around  reg_alpha
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_alpha 0.22499999999999998
# new score: 0.5384033613445378
# old score 0.543249299719888
# walking around  reg_lambda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_lambda 0.675
# new score: 0.5349719887955182
# old score 0.543249299719888
# walking around  gamma
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters gamma 0.0
# new score: 0.543249299719888
# old score 0.543249299719888
# walking around  subsample
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters subsample 0.1875
# new score: 0.5005742296918768
# old score 0.543249299719888
# walking around  colsample_bytree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters colsample_bytree 0.3375
# new score: 0.505420168067227
# old score 0.543249299719888
# walking around  scale_pos_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters scale_pos_weight 1
# new score: 0.543249299719888
# old score 0.543249299719888
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 10
# new score: 0.543249299719888
# old score 0.543249299719888
# calculating candidates on test set:
# 1. best tunned model based on cv validation
# 2. best tunned model based on minimun std
# 3. first model (with default parameters)
# 4. second model (with default parameters)
# expected_score_1,expected_score_2 0.5333333333333333 0.4533333333333333
# expected_score_3,expected_score_4 0.4733333333333333 0.54
# results_on_test_dict {1: 0.5333333333333333, 2: 0.4533333333333333, 3: 0.4733333333333333, 4: 0.54}
# selected_key 4
# l [None, 0.9692296918767506, 0.54, 'XGB', None]
# saving scaler at /home/gari/Desktop/master_tesis_v3/MLDiagnosisTool/eeg_alpha_beta/eeg_alpha_beta_scaler.file
# Raw accuracy 0.48598130841121495
# accuracy 0.4883720930232558
# f1_score 0.5925925925925926
# recall 0.463768115942029
# precision 0.8205128205128205
# selected_model: XGB
# selected parameters: None
# score on test set of data: 0.54
# Do not forget to see your report in: /home/gari/Desktop/master_tesis_v3/MLDiagnosisTool/eeg_alpha_beta
# --- 948.9198265075684 seconds ---
# EEG 0.54

# %%
#experiment="entropy"

#run_experiment(experiment)

# %%
#experiment="delta_theta_alpha_beta_entropy"

#run_experiment(experiment)

# %%
#experiment="delta_theta_alpha_entropy"

#run_experiment(experiment)

# %%
#experiment="delta_theta_entropy"

#run_experiment(experiment)

# %%
#xperiment="delta_entropy"

#un_experiment(experiment)

# %%
#experiment="entropy"

#run_experiment(experiment)

# %%
#experiment="entropy_delta_theta"

#run_experiment(experiment)

# %%
#path_clf="/home/gari/Desktop/master_tesis_v3/MLDiagnosisTool/iter_2/eeg_entropy/eeg_entropy_clf.file"
#clf=OFH.load_object(path_clf)

# %%
#clf.classes_

# %%
#df_id=OFH.load_object("/home/gari/Desktop/master_tesis_v3/Data/IdDataSet/df_test_identity.file")

# %%
#df_id
