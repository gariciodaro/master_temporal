# %%
import os
import sys

sys.path.append("/home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/")
sys.path.append("/home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/Classes/")
sys.path.append("/home/gari/Desktop/master_tesis_v2/")

from OFHandlers import OFHandlers as OFH
import CoreML
import pandas as pd
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import SelectKBest, chi2
# Out:
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.bagging module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
def run_experiment(experiment):
    #experiment="_entropy_delta_theta"
    data_co="/home/gari/Desktop/master_tesis_v2/Data/Datasets_"
    data_origin=data_co+experiment+"/prepared_train_data_set.file"
    
    data_test_path=data_co+experiment+"/prepared_test_data_set.file"


    note_exp=experiment

    data=OFH.load_object(data_origin)
    score_1=CoreML.core_diagnosis(data_origin=data,
                      data_origin_string="object_dataframe",
                      name="/eeg_"+experiment,
                      string_metric="roc_auc_score",
                      number_of_clusters=200,
                      hiper_tunning_iters=30,
                      futher_op_boo=True,
                      balance_train=False,
                      clustering=True,
                      polynomial=True,
                      test_size=0.2,
                      path_to_test=data_test_path,
                      note_exp=note_exp)
    print("EEG",score_1)

# %%
experiment="all_power_bands"

run_experiment(experiment)
# Out:
# categorical_columns Index([], dtype='object')
#             0         1         2         3         4         5         6  \
# 0    0.710053  0.154375  0.112361  0.023211  0.673089  0.163235  0.135055
# 1    0.706104  0.137911  0.133896  0.022090  0.699184  0.127034  0.147558
# 2    0.774367  0.129987  0.080810  0.014836  0.787049  0.104337  0.092860
# 3    0.673525  0.160555  0.139623  0.026297  0.638863  0.149104  0.182793
# 4    0.755188  0.128808  0.099585  0.016419  0.732251  0.128041  0.120492
# ..        ...       ...       ...       ...       ...       ...       ...
# 990  0.768916  0.142740  0.068189  0.020155  0.846233  0.086003  0.052153
# 991  0.734641  0.179887  0.063818  0.021654  0.810500  0.129774  0.042770
# 992  0.710368  0.182840  0.078484  0.028307  0.778035  0.145555  0.051657
# 993  0.751620  0.144237  0.079804  0.024340  0.817576  0.103941  0.054841
# 994  0.744385  0.131744  0.098037  0.025834  0.828992  0.090900  0.058867
#
#             7         8         9  ...       431       432       433  \
# 0    0.028621  0.896782  0.062786  ...  0.016562  0.814169  0.094598
# 1    0.026224  0.926069  0.040975  ...  0.015842  0.783362  0.093159
# 2    0.015754  0.919943  0.058315  ...  0.008639  0.839726  0.083272
# 3    0.029241  0.939211  0.031990  ...  0.013694  0.748032  0.106801
# 4    0.019216  0.925613  0.046021  ...  0.010878  0.802972  0.099438
# ..        ...       ...       ...  ...       ...       ...       ...
# 990  0.015612  0.965749  0.020573  ...  0.005187  0.636125  0.218136
# 991  0.016956  0.951981  0.029441  ...  0.005112  0.664630  0.225804
# 992  0.024753  0.932531  0.038837  ...  0.011159  0.678932  0.211379
# 993  0.023641  0.941502  0.035951  ...  0.007173  0.629771  0.218417
# 994  0.021242  0.948033  0.030925  ...  0.006191  0.619517  0.226447
#
#           434       435       436       437       438       439  440
# 0    0.073320  0.017913  0.794942  0.104656  0.079279  0.021124  0.0
# 1    0.104936  0.018543  0.725556  0.123757  0.127691  0.022997  0.0
# 2    0.065236  0.011765  0.779125  0.124423  0.079929  0.016523  0.0
# 3    0.128119  0.017048  0.686124  0.134365  0.158061  0.021451  0.0
# 4    0.084324  0.013267  0.757020  0.127743  0.097547  0.017690  0.0
# ..        ...       ...       ...       ...       ...       ...  ...
# 990  0.116975  0.028764  0.763023  0.148261  0.070648  0.018068  0.0
# 991  0.084983  0.024583  0.796511  0.138618  0.049400  0.015472  0.0
# 992  0.080067  0.029623  0.773936  0.154297  0.049788  0.021979  0.0
# 993  0.110171  0.041641  0.775656  0.139883  0.060904  0.023557  0.0
# 994  0.118564  0.035472  0.801778  0.132214  0.048184  0.017824  0.0
#
# [995 rows x 441 columns]
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# Categorical data not detected.
# models ['RF', 'XGB']
# scores [0.44495798319327723, 0.4795378151260504]
# max_mean_cv_validation for no-clustering no-polynomial 0.4795378151260504
# models ['RF', 'XGB']
# scores [0.4661764705882353, 0.4606442577030812]
# max_mean_cv_validation for clustering 0.4661764705882353
# models ['RF', 'XGB']
# scores [0.4935434173669468, 0.4852801120448179]
# max_mean_cv_validation for for polynomial 0.4935434173669468
# score_mean_dict {0: 0.4795378151260504, 1: 0.4661764705882353, 2: 0.4935434173669468}
# temp_dic {'RF': 0.4935434173669468, 'XGB': 0.4852801120448179}
# selected second:  XGB 0.4852801120448179
# Starting hiper parameters tunning...
# hiper tunning results on RF
#      index name_model validation score  \
# 0      10         RF         0.522045
# 1      20         RF         0.512437
# 2      12         RF          0.50423
# 3      21         RF         0.502997
# 4       2         RF         0.502885
# 5      15         RF         0.501779
# 6       1         RF          0.50063
# 7      22         RF         0.499482
# 8      19         RF         0.499342
# 9       8         RF         0.498319
# 10      0         RF         0.498277
# 11     25         RF         0.496989
# 12     26         RF         0.495966
# 13     18         RF         0.495952
# 14     24         RF         0.494776
# 15      3         RF         0.494692
# 16     28         RF         0.494678
# 17     11         RF         0.494594
# 18     16         RF         0.493627
# 19      7         RF         0.492367
# 20     17         RF         0.491022
# 21      9         RF         0.489888
# 22      6         RF         0.489594
# 23      4         RF          0.48395
# 24     14         RF         0.482913
# 25     29         RF         0.482759
# 26     23         RF         0.480406
# 27     27         RF         0.469818
# 28     13         RF         0.469818
# 29      5         RF         0.458992
#
#                                                params iteration
# 0   {'n_estimators': 18, 'random_state': 0, 'max_f...        10
# 1   {'n_estimators': 35, 'random_state': 13, 'max_...        20
# 2   {'n_estimators': 18, 'random_state': 0, 'max_f...        12
# 3   {'n_estimators': 35, 'random_state': 13, 'max_...        21
# 4   {'n_estimators': 86, 'random_state': 13, 'max_...         2
# 5   {'n_estimators': 35, 'random_state': 13, 'max_...        15
# 6   {'n_estimators': 89, 'random_state': 0, 'max_f...         1
# 7   {'n_estimators': 59, 'random_state': 13, 'max_...        22
# 8   {'n_estimators': 48, 'random_state': 13, 'max_...        19
# 9   {'n_estimators': 24, 'random_state': 0, 'max_f...         8
# 10  {'n_estimators': 100, 'random_state': 0, 'max_...         0
# 11  {'n_estimators': 38, 'random_state': 13, 'max_...        25
# 12  {'n_estimators': 11, 'random_state': 13, 'max_...        26
# 13  {'n_estimators': 11, 'random_state': 0, 'max_f...        18
# 14  {'n_estimators': 35, 'random_state': 42, 'max_...        24
# 15  {'n_estimators': 72, 'random_state': 10, 'max_...         3
# 16  {'n_estimators': 79, 'random_state': 10, 'max_...        28
# 17  {'n_estimators': 7, 'random_state': 0, 'max_fe...        11
# 18  {'n_estimators': 59, 'random_state': 13, 'max_...        16
# 19  {'n_estimators': 96, 'random_state': 0, 'max_f...         7
# 20  {'n_estimators': 100, 'random_state': 0, 'max_...        17
# 21  {'n_estimators': 59, 'random_state': 42, 'max_...         9
# 22  {'n_estimators': 14, 'random_state': 10, 'max_...         6
# 23  {'n_estimators': 62, 'random_state': 0, 'max_f...         4
# 24  {'n_estimators': 59, 'random_state': 0, 'max_f...        14
# 25  {'n_estimators': 96, 'random_state': 10, 'max_...        29
# 26  {'n_estimators': 76, 'random_state': 0, 'max_f...        23
# 27  {'n_estimators': 28, 'random_state': 13, 'max_...        27
# 28  {'n_estimators': 28, 'random_state': 13, 'max_...        13
# 29  {'n_estimators': 4, 'random_state': 0, 'max_fe...         5
# hiper tunning results on XGB
#      index name_model validation score  \
# 0       9        XGB         0.526653
# 1      23        XGB          0.51965
# 2      29        XGB         0.516078
# 3       5        XGB         0.515966
# 4      10        XGB         0.515966
# 5       1        XGB         0.515014
# 6      17        XGB         0.513669
# 7      18        XGB         0.510126
# 8       6        XGB         0.510126
# 9      14        XGB         0.506723
# 10     19        XGB          0.50542
# 11     16        XGB         0.505364
# 12      2        XGB          0.50423
# 13      4        XGB         0.503179
# 14     25        XGB         0.503095
# 15     20        XGB         0.503053
# 16     11        XGB         0.501807
# 17     21        XGB         0.498431
# 18      7        XGB         0.498263
# 19     13        XGB         0.497101
# 20      3        XGB         0.497017
# 21     28        XGB         0.495994
# 22     15        XGB         0.495938
# 23     22        XGB         0.494762
# 24     26        XGB         0.492451
# 25      0        XGB         0.491218
# 26     24        XGB          0.49112
# 27     12        XGB         0.486541
# 28      8        XGB         0.486457
# 29     27        XGB         0.479328
#
#                                                params iteration
# 0   {'min_child_weight': 1, 'max_depth': 7, 'learn...         9
# 1   {'min_child_weight': 1, 'max_depth': 9, 'learn...        23
# 2   {'min_child_weight': 1, 'max_depth': 9, 'learn...        29
# 3   {'min_child_weight': 1, 'max_depth': 3, 'learn...         5
# 4   {'min_child_weight': 1, 'max_depth': 3, 'learn...        10
# 5   {'min_child_weight': 1, 'max_depth': 9, 'learn...         1
# 6   {'min_child_weight': 1, 'max_depth': 10, 'lear...        17
# 7   {'min_child_weight': 1, 'max_depth': 9, 'learn...        18
# 8   {'min_child_weight': 1, 'max_depth': 10, 'lear...         6
# 9   {'min_child_weight': 1, 'max_depth': 10, 'lear...        14
# 10  {'min_child_weight': 1, 'max_depth': 9, 'learn...        19
# 11  {'min_child_weight': 1, 'max_depth': 7, 'learn...        16
# 12  {'min_child_weight': 1, 'max_depth': 9, 'learn...         2
# 13  {'min_child_weight': 1, 'max_depth': 10, 'lear...         4
# 14  {'min_child_weight': 1, 'max_depth': 9, 'learn...        25
# 15  {'min_child_weight': 1, 'max_depth': 10, 'lear...        20
# 16  {'min_child_weight': 1, 'max_depth': 9, 'learn...        11
# 17  {'min_child_weight': 1, 'max_depth': 7, 'learn...        21
# 18  {'min_child_weight': 1, 'max_depth': 9, 'learn...         7
# 19  {'min_child_weight': 1, 'max_depth': 3, 'learn...        13
# 20  {'min_child_weight': 1, 'max_depth': 3, 'learn...         3
# 21  {'min_child_weight': 1, 'max_depth': 10, 'lear...        28
# 22  {'min_child_weight': 1, 'max_depth': 10, 'lear...        15
# 23  {'min_child_weight': 1, 'max_depth': 7, 'learn...        22
# 24  {'min_child_weight': 1, 'max_depth': 10, 'lear...        26
# 25  {'min_child_weight': 1, 'max_depth': 3, 'learn...         0
# 26  {'min_child_weight': 1, 'max_depth': 3, 'learn...        24
# 27  {'min_child_weight': 1, 'max_depth': 3, 'learn...        12
# 28  {'min_child_weight': 1, 'max_depth': 7, 'learn...         8
# 29  {'min_child_weight': 1, 'max_depth': 10, 'lear...        27
# before walking around hyperparameters
# RF 0.5220448179271708
# XGB 0.5266526610644258
# first futher op
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 30
# new score: 0.5267927170868347
# old score 0.5220448179271708
# walking around  min_samples_split
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_split 9
# new score: 0.5350840336134454
# old score 0.5267927170868347
# walking around  min_samples_leaf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_leaf 4
# new score: 0.5350840336134454
# old score 0.5350840336134454
# walking around  bootstrap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters bootstrap -9
# new score: 0.5350840336134454
# old score 0.5350840336134454
# second futher op
# walking around  min_child_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_child_weight 4
# new score: 0.5327310924369748
# old score 0.5266526610644258
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 7
# new score: 0.5327310924369748
# old score 0.5327310924369748
# walking around  learning_rate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters learning_rate 0.06
# new score: 0.5207002801120448
# old score 0.5327310924369748
# walking around  reg_alpha
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_alpha 0.0075
# new score: 0.5326470588235294
# old score 0.5327310924369748
# walking around  reg_lambda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_lambda 0.9000000000000001
# new score: 0.5315266106442577
# old score 0.5327310924369748
# walking around  gamma
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters gamma 0.0
# new score: 0.5327310924369748
# old score 0.5327310924369748
# walking around  subsample
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters subsample 0.0
# new score: 0.5
# old score 0.5327310924369748
# walking around  colsample_bytree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters colsample_bytree 0.675
# new score: 0.505420168067227
# old score 0.5327310924369748
# walking around  scale_pos_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters scale_pos_weight 1
# new score: 0.5327310924369748
# old score 0.5327310924369748
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 54
# new score: 0.5327591036414565
# old score 0.5327310924369748
# calculating candidates on test set:
# 1. best tunned model based on cv validation
# 2. best tunned model based on minimun std
# 3. first model (with default parameters)
# 4. second model (with default parameters)
# expected_score_1,expected_score_2 0.56 0.5866666666666667
# expected_score_3,expected_score_4 0.5933333333333333 0.54
# results_on_test_dict {1: 0.56, 2: 0.5866666666666667, 3: 0.5933333333333333, 4: 0.54}
# selected_key 3
# l [None, 1.0, 0.5933333333333333, 'RF', None]
# saving scaler at /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_all_power_bands/eeg_all_power_bands_scaler.file
# Raw accuracy 0.47113702623906706
# ajusted_acc 0.4957374254049446
# selected_model: RF
# selected parameters: None
# score on test set of data: 0.5933333333333333
# Do not forget to see your report in: /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_all_power_bands
# --- 1280.4026193618774 seconds ---
# EEG 0.5933333333333333

# %%
experiment="delta_theta"

run_experiment(experiment)
# Out:
# categorical_columns Index([], dtype='object')
#             0         1         2         3         4         5         6  \
# 0    0.710053  0.154375  0.673089  0.163235  0.896782  0.062786  0.894461
# 1    0.706104  0.137911  0.699184  0.127034  0.926069  0.040975  0.924477
# 2    0.774367  0.129987  0.787049  0.104337  0.919943  0.058315  0.918186
# 3    0.673525  0.160555  0.638863  0.149104  0.939211  0.031990  0.936929
# 4    0.755188  0.128808  0.732251  0.128041  0.925613  0.046021  0.923918
# ..        ...       ...       ...       ...       ...       ...       ...
# 990  0.768916  0.142740  0.846233  0.086003  0.965749  0.020573  0.899205
# 991  0.734641  0.179887  0.810500  0.129774  0.951981  0.029441  0.869593
# 992  0.710368  0.182840  0.778035  0.145555  0.932531  0.038837  0.862491
# 993  0.751620  0.144237  0.817576  0.103941  0.941502  0.035951  0.886195
# 994  0.744385  0.131744  0.828992  0.090900  0.948033  0.030925  0.888940
#
#             7         8         9  ...       211       212       213  \
# 0    0.064521  0.803025  0.095103  ...  0.118238  0.724282  0.143397
# 1    0.040696  0.738980  0.129414  ...  0.106026  0.645808  0.158099
# 2    0.057361  0.774419  0.130173  ...  0.139494  0.806882  0.099338
# 3    0.031391  0.718696  0.121402  ...  0.108235  0.691532  0.159799
# 4    0.045144  0.778855  0.116972  ...  0.133165  0.738376  0.127792
# ..        ...       ...       ...  ...       ...       ...       ...
# 990  0.047060  0.807408  0.090060  ...  0.162678  0.694847  0.194484
# 991  0.083203  0.772897  0.147869  ...  0.197470  0.655127  0.234523
# 992  0.086163  0.801285  0.131209  ...  0.164059  0.679433  0.200112
# 993  0.065934  0.804049  0.112320  ...  0.162366  0.680772  0.191570
# 994  0.057172  0.815302  0.096264  ...  0.128732  0.666772  0.169091
#
#           214       215       216       217       218       219  220
# 0    0.794526  0.119187  0.814169  0.094598  0.794942  0.104656  0.0
# 1    0.753555  0.114119  0.783362  0.093159  0.725556  0.123757  0.0
# 2    0.866399  0.076496  0.839726  0.083272  0.779125  0.124423  0.0
# 3    0.804588  0.096159  0.748032  0.106801  0.686124  0.134365  0.0
# 4    0.828966  0.087832  0.802972  0.099438  0.757020  0.127743  0.0
# ..        ...       ...       ...       ...       ...       ...  ...
# 990  0.965886  0.018862  0.636125  0.218136  0.763023  0.148261  0.0
# 991  0.959453  0.023325  0.664630  0.225804  0.796511  0.138618  0.0
# 992  0.938932  0.031232  0.678932  0.211379  0.773936  0.154297  0.0
# 993  0.952821  0.029409  0.629771  0.218417  0.775656  0.139883  0.0
# 994  0.950227  0.030943  0.619517  0.226447  0.801778  0.132214  0.0
#
# [995 rows x 221 columns]
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# Categorical data not detected.
# models ['RF', 'XGB']
# scores [0.5099019607843137, 0.4818767507002802]
# max_mean_cv_validation for no-clustering no-polynomial 0.5099019607843137
# models ['RF', 'XGB']
# scores [0.45549019607843144, 0.45796918767507]
# max_mean_cv_validation for clustering 0.45796918767507
# models ['RF', 'XGB']
# scores [0.5001820728291316, 0.5097198879551821]
# max_mean_cv_validation for for polynomial 0.5097198879551821
# score_mean_dict {0: 0.5099019607843137, 1: 0.45796918767507, 2: 0.5097198879551821}
# temp_dic {'RF': 0.5099019607843137, 'XGB': 0.4818767507002802}
# selected second:  XGB 0.4818767507002802
# Starting hiper parameters tunning...
# hiper tunning results on RF
#      index name_model validation score  \
# 0      13         RF         0.524734
# 1       4         RF         0.524174
# 2      10         RF         0.524132
# 3      21         RF         0.523263
# 4      15         RF         0.520602
# 5       0         RF         0.519608
# 6       3         RF         0.518403
# 7      24         RF         0.518375
# 8      18         RF         0.515784
# 9      29         RF         0.513543
# 10      9         RF         0.512143
# 11     19         RF         0.511232
# 12     14         RF         0.511176
# 13     23         RF         0.509944
# 14      1         RF         0.506373
# 15     17         RF         0.505056
# 16      6         RF         0.502969
# 17      8         RF         0.502801
# 18      7         RF         0.501667
# 19     12         RF         0.501401
# 20      2         RF         0.498193
# 21     11         RF         0.496989
# 22     25         RF         0.496989
# 23     27         RF          0.49451
# 24     20         RF         0.492171
# 25     26         RF         0.490742
# 26     28         RF         0.489888
# 27      5         RF         0.488711
# 28     22         RF         0.478081
# 29     16         RF         0.477703
#
#                                                params iteration
# 0   {'n_estimators': 4, 'random_state': 13, 'max_f...        13
# 1   {'n_estimators': 89, 'random_state': 10, 'max_...         4
# 2   {'n_estimators': 93, 'random_state': 0, 'max_f...        10
# 3   {'n_estimators': 1, 'random_state': 10, 'max_f...        21
# 4   {'n_estimators': 69, 'random_state': 0, 'max_f...        15
# 5   {'n_estimators': 28, 'random_state': 10, 'max_...         0
# 6   {'n_estimators': 59, 'random_state': 42, 'max_...         3
# 7   {'n_estimators': 65, 'random_state': 13, 'max_...        24
# 8   {'n_estimators': 11, 'random_state': 13, 'max_...        18
# 9   {'n_estimators': 35, 'random_state': 0, 'max_f...        29
# 10  {'n_estimators': 65, 'random_state': 0, 'max_f...         9
# 11  {'n_estimators': 76, 'random_state': 10, 'max_...        19
# 12  {'n_estimators': 76, 'random_state': 0, 'max_f...        14
# 13  {'n_estimators': 89, 'random_state': 0, 'max_f...        23
# 14  {'n_estimators': 24, 'random_state': 10, 'max_...         1
# 15  {'n_estimators': 48, 'random_state': 42, 'max_...        17
# 16  {'n_estimators': 89, 'random_state': 13, 'max_...         6
# 17  {'n_estimators': 82, 'random_state': 0, 'max_f...         8
# 18  {'n_estimators': 35, 'random_state': 0, 'max_f...         7
# 19  {'n_estimators': 4, 'random_state': 0, 'max_fe...        12
# 20  {'n_estimators': 76, 'random_state': 42, 'max_...         2
# 21  {'n_estimators': 69, 'random_state': 42, 'max_...        11
# 22  {'n_estimators': 48, 'random_state': 0, 'max_f...        25
# 23  {'n_estimators': 96, 'random_state': 42, 'max_...        27
# 24  {'n_estimators': 59, 'random_state': 10, 'max_...        20
# 25  {'n_estimators': 4, 'random_state': 13, 'max_f...        26
# 26  {'n_estimators': 65, 'random_state': 0, 'max_f...        28
# 27  {'n_estimators': 72, 'random_state': 42, 'max_...         5
# 28  {'n_estimators': 28, 'random_state': 42, 'max_...        22
# 29  {'n_estimators': 52, 'random_state': 0, 'max_f...        16
# hiper tunning results on XGB
#      index name_model validation score  \
# 0       9        XGB         0.514972
# 1      26        XGB          0.51479
# 2      18        XGB          0.51479
# 3       3        XGB         0.505462
# 4       8        XGB          0.50423
# 5      28        XGB         0.504146
# 6       0        XGB         0.502997
# 7      12        XGB         0.501695
# 8      15        XGB         0.499496
# 9      25        XGB         0.499426
# 10     13        XGB         0.498375
# 11     11        XGB         0.495812
# 12     29        XGB          0.49458
# 13     21        XGB         0.494552
# 14      7        XGB         0.493501
# 15     19        XGB         0.492451
# 16     24        XGB         0.489972
# 17      5        XGB         0.486527
# 18     20        XGB         0.485252
# 19     10        XGB          0.48514
# 20     16        XGB         0.482941
# 21      4        XGB         0.482885
# 22     14        XGB         0.481709
# 23      2        XGB         0.481639
# 24      1        XGB         0.480518
# 25     22        XGB         0.479328
# 26     17        XGB         0.479202
# 27      6        XGB          0.47458
# 28     23        XGB         0.472367
# 29     27        XGB         0.466373
#
#                                                params iteration
# 0   {'min_child_weight': 1, 'max_depth': 9, 'learn...         9
# 1   {'min_child_weight': 1, 'max_depth': 7, 'learn...        26
# 2   {'min_child_weight': 1, 'max_depth': 9, 'learn...        18
# 3   {'min_child_weight': 1, 'max_depth': 3, 'learn...         3
# 4   {'min_child_weight': 1, 'max_depth': 7, 'learn...         8
# 5   {'min_child_weight': 1, 'max_depth': 3, 'learn...        28
# 6   {'min_child_weight': 1, 'max_depth': 9, 'learn...         0
# 7   {'min_child_weight': 1, 'max_depth': 10, 'lear...        12
# 8   {'min_child_weight': 1, 'max_depth': 10, 'lear...        15
# 9   {'min_child_weight': 1, 'max_depth': 3, 'learn...        25
# 10  {'min_child_weight': 1, 'max_depth': 3, 'learn...        13
# 11  {'min_child_weight': 1, 'max_depth': 9, 'learn...        11
# 12  {'min_child_weight': 1, 'max_depth': 7, 'learn...        29
# 13  {'min_child_weight': 1, 'max_depth': 7, 'learn...        21
# 14  {'min_child_weight': 1, 'max_depth': 9, 'learn...         7
# 15  {'min_child_weight': 1, 'max_depth': 7, 'learn...        19
# 16  {'min_child_weight': 1, 'max_depth': 9, 'learn...        24
# 17  {'min_child_weight': 1, 'max_depth': 9, 'learn...         5
# 18  {'min_child_weight': 1, 'max_depth': 9, 'learn...        20
# 19  {'min_child_weight': 1, 'max_depth': 7, 'learn...        10
# 20  {'min_child_weight': 1, 'max_depth': 7, 'learn...        16
# 21  {'min_child_weight': 1, 'max_depth': 7, 'learn...         4
# 22  {'min_child_weight': 1, 'max_depth': 10, 'lear...        14
# 23  {'min_child_weight': 1, 'max_depth': 7, 'learn...         2
# 24  {'min_child_weight': 1, 'max_depth': 3, 'learn...         1
# 25  {'min_child_weight': 1, 'max_depth': 9, 'learn...        22
# 26  {'min_child_weight': 1, 'max_depth': 9, 'learn...        17
# 27  {'min_child_weight': 1, 'max_depth': 7, 'learn...         6
# 28  {'min_child_weight': 1, 'max_depth': 10, 'lear...        23
# 29  {'min_child_weight': 1, 'max_depth': 7, 'learn...        27
# before walking around hyperparameters
# RF 0.524733893557423
# XGB 0.5149719887955182
# first futher op
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 36
# new score: 0.5313725490196078
# old score 0.524733893557423
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 100
# new score: 0.5313725490196078
# old score 0.5313725490196078
# walking around  min_samples_split
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_split 2
# new score: 0.5313725490196078
# old score 0.5313725490196078
# walking around  min_samples_leaf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_leaf 3
# new score: 0.5383193277310925
# old score 0.5313725490196078
# walking around  bootstrap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters bootstrap -9
# new score: 0.5383193277310925
# old score 0.5383193277310925
# second futher op
# walking around  min_child_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_child_weight 4
# new score: 0.5161764705882353
# old score 0.5149719887955182
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 11
# new score: 0.5374089635854341
# old score 0.5161764705882353
# walking around  learning_rate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters learning_rate 1.0125
# new score: 0.5373389355742297
# old score 0.5374089635854341
# walking around  reg_alpha
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_alpha 0.0075
# new score: 0.5362324929971989
# old score 0.5374089635854341
# walking around  reg_lambda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_lambda 1
# new score: 0.5374089635854341
# old score 0.5374089635854341
# walking around  gamma
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters gamma 0.0
# new score: 0.5374089635854341
# old score 0.5374089635854341
# walking around  subsample
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters subsample 0.675
# new score: 0.516078431372549
# old score 0.5374089635854341
# walking around  colsample_bytree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters colsample_bytree 0.5249999999999999
# new score: 0.5100980392156863
# old score 0.5374089635854341
# walking around  scale_pos_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters scale_pos_weight 1
# new score: 0.5374089635854341
# old score 0.5374089635854341
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 196
# new score: 0.5385854341736694
# old score 0.5374089635854341
# calculating candidates on test set:
# 1. best tunned model based on cv validation
# 2. best tunned model based on minimun std
# 3. first model (with default parameters)
# 4. second model (with default parameters)
# expected_score_1,expected_score_2 0.6000000000000001 0.5866666666666667
# expected_score_3,expected_score_4 0.56 0.58
# results_on_test_dict {1: 0.6000000000000001, 2: 0.5866666666666667, 3: 0.56, 4: 0.58}
# selected_key 1
# l [{'n_estimators': 36, 'random_state': 13, 'max_features': 'auto', 'max_depth': 110, 'min_samples_split': 2, 'min_samples_leaf': 3, 'bootstrap': True}, 0.9988095238095238, 0.6000000000000001, 'RF', 1.358543417366953]
# saving scaler at /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_delta_theta/eeg_delta_theta_scaler.file
# Raw accuracy 0.5019550677413823
# ajusted_acc 0.5323955669224212
# selected_model: RF
# selected parameters: {'n_estimators': 36, 'random_state': 13, 'max_features': 'auto', 'max_depth': 110, 'min_samples_split': 2, 'min_samples_leaf': 3, 'bootstrap': True}
# score on test set of data: 0.6000000000000001
# Do not forget to see your report in: /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_delta_theta
# --- 1472.7599108219147 seconds ---
# EEG 0.6000000000000001

# %%
experiment="alpha_beta"

run_experiment(experiment)
# Out:
# categorical_columns Index([], dtype='object')
#             0         1         2         3         4         5         6  \
# 0    0.112361  0.023211  0.135055  0.028621  0.029584  0.010847  0.030005
# 1    0.133896  0.022090  0.147558  0.026224  0.028139  0.004817  0.029635
# 2    0.080810  0.014836  0.092860  0.015754  0.017251  0.004491  0.019462
# 3    0.139623  0.026297  0.182793  0.029241  0.023117  0.005682  0.025782
# 4    0.099585  0.016419  0.120492  0.019216  0.021477  0.006889  0.023565
# ..        ...       ...       ...       ...       ...       ...       ...
# 990  0.068189  0.020155  0.052153  0.015612  0.008540  0.005137  0.043223
# 991  0.063818  0.021654  0.042770  0.016956  0.012039  0.006539  0.034084
# 992  0.078484  0.028307  0.051657  0.024753  0.016637  0.011995  0.033036
# 993  0.079804  0.024340  0.054841  0.023641  0.013874  0.008673  0.032985
# 994  0.098037  0.025834  0.058867  0.021242  0.013265  0.007776  0.037809
#
#             7         8         9  ...       211       212       213  \
# 0    0.011013  0.083127  0.018745  ...  0.019857  0.112252  0.020070
# 1    0.005192  0.113391  0.018215  ...  0.012417  0.174670  0.021423
# 2    0.004991  0.080400  0.015008  ...  0.013921  0.080488  0.013291
# 3    0.005899  0.141468  0.018433  ...  0.011787  0.130650  0.018019
# 4    0.007373  0.087667  0.016506  ...  0.015183  0.119168  0.014663
# ..        ...       ...       ...  ...       ...       ...       ...
# 990  0.010511  0.086169  0.016362  ...  0.021013  0.086872  0.023797
# 991  0.013120  0.058749  0.020486  ...  0.022669  0.084664  0.025686
# 992  0.018311  0.044267  0.023238  ...  0.025893  0.090849  0.029607
# 993  0.014886  0.060582  0.023049  ...  0.024574  0.099127  0.028531
# 994  0.016079  0.063916  0.024518  ...  0.025085  0.133622  0.030514
#
#           214       215       216       217       218       219  220
# 0    0.069725  0.016562  0.073320  0.017913  0.079279  0.021124  0.0
# 1    0.116485  0.015842  0.104936  0.018543  0.127691  0.022997  0.0
# 2    0.048466  0.008639  0.065236  0.011765  0.079929  0.016523  0.0
# 3    0.085559  0.013694  0.128119  0.017048  0.158061  0.021451  0.0
# 4    0.072323  0.010878  0.084324  0.013267  0.097547  0.017690  0.0
# ..        ...       ...       ...       ...       ...       ...  ...
# 990  0.010065  0.005187  0.116975  0.028764  0.070648  0.018068  0.0
# 991  0.012111  0.005112  0.084983  0.024583  0.049400  0.015472  0.0
# 992  0.018677  0.011159  0.080067  0.029623  0.049788  0.021979  0.0
# 993  0.010598  0.007173  0.110171  0.041641  0.060904  0.023557  0.0
# 994  0.012639  0.006191  0.118564  0.035472  0.048184  0.017824  0.0
#
# [995 rows x 221 columns]
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# Categorical data not detected.
# models ['RF', 'XGB']
# scores [0.466218487394958, 0.456750700280112]
# max_mean_cv_validation for no-clustering no-polynomial 0.466218487394958
# models ['RF', 'XGB']
# scores [0.4223669467787114, 0.42935574229691886]
# max_mean_cv_validation for clustering 0.42935574229691886
# models ['RF', 'XGB']
# scores [0.49471988795518207, 0.46865546218487397]
# max_mean_cv_validation for for polynomial 0.49471988795518207
# score_mean_dict {0: 0.466218487394958, 1: 0.42935574229691886, 2: 0.49471988795518207}
# temp_dic {'RF': 0.49471988795518207, 'XGB': 0.46865546218487397}
# selected second:  XGB 0.46865546218487397
# Starting hiper parameters tunning...
# hiper tunning results on RF
#      index name_model validation score  \
# 0      24         RF         0.520826
# 1      14         RF         0.520742
# 2      19         RF         0.517241
# 3       0         RF         0.514888
# 4       4         RF         0.513782
# 5      16         RF         0.512563
# 6       3         RF         0.512507
# 7       8         RF         0.510196
# 8      17         RF         0.508992
# 9      11         RF         0.507759
# 10     10         RF         0.506569
# 11     22         RF         0.504272
# 12      2         RF         0.504216
# 13      1         RF         0.503109
# 14     13         RF         0.502339
# 15     23         RF         0.502297
# 16     20         RF         0.501863
# 17     27         RF         0.500742
# 18     25         RF          0.49951
# 19     12         RF         0.499454
# 20      5         RF         0.499356
# 21      9         RF         0.496036
# 22     29         RF         0.494762
# 23      7         RF         0.492339
# 24     18         RF         0.492311
# 25      6         RF         0.492297
# 26     28         RF          0.48881
# 27     15         RF         0.485812
# 28     21         RF         0.482773
# 29     26         RF         0.481905
#
#                                                params iteration
# 0   {'n_estimators': 62, 'random_state': 13, 'max_...        24
# 1   {'n_estimators': 38, 'random_state': 42, 'max_...        14
# 2   {'n_estimators': 38, 'random_state': 10, 'max_...        19
# 3   {'n_estimators': 79, 'random_state': 10, 'max_...         0
# 4   {'n_estimators': 82, 'random_state': 10, 'max_...         4
# 5   {'n_estimators': 31, 'random_state': 10, 'max_...        16
# 6   {'n_estimators': 55, 'random_state': 13, 'max_...         3
# 7   {'n_estimators': 76, 'random_state': 10, 'max_...         8
# 8   {'n_estimators': 48, 'random_state': 42, 'max_...        17
# 9   {'n_estimators': 38, 'random_state': 10, 'max_...        11
# 10  {'n_estimators': 14, 'random_state': 13, 'max_...        10
# 11  {'n_estimators': 18, 'random_state': 13, 'max_...        22
# 12  {'n_estimators': 38, 'random_state': 0, 'max_f...         2
# 13  {'n_estimators': 18, 'random_state': 10, 'max_...         1
# 14  {'n_estimators': 4, 'random_state': 42, 'max_f...        13
# 15  {'n_estimators': 4, 'random_state': 0, 'max_fe...        23
# 16  {'n_estimators': 93, 'random_state': 42, 'max_...        20
# 17  {'n_estimators': 11, 'random_state': 10, 'max_...        27
# 18  {'n_estimators': 24, 'random_state': 10, 'max_...        25
# 19  {'n_estimators': 48, 'random_state': 42, 'max_...        12
# 20  {'n_estimators': 48, 'random_state': 42, 'max_...         5
# 21  {'n_estimators': 14, 'random_state': 0, 'max_f...         9
# 22  {'n_estimators': 59, 'random_state': 13, 'max_...        29
# 23  {'n_estimators': 93, 'random_state': 13, 'max_...         7
# 24  {'n_estimators': 65, 'random_state': 0, 'max_f...        18
# 25  {'n_estimators': 100, 'random_state': 10, 'max...         6
# 26  {'n_estimators': 86, 'random_state': 13, 'max_...        28
# 27  {'n_estimators': 4, 'random_state': 13, 'max_f...        15
# 28  {'n_estimators': 52, 'random_state': 42, 'max_...        21
# 29  {'n_estimators': 11, 'random_state': 10, 'max_...        26
# hiper tunning results on XGB
#      index name_model validation score  \
# 0       3        XGB          0.51619
# 1      24        XGB         0.511289
# 2      23        XGB         0.509048
# 3       7        XGB         0.504356
# 4      19        XGB         0.503067
# 5      27        XGB         0.501933
# 6      10        XGB         0.501919
# 7       8        XGB         0.498487
# 8      15        XGB         0.498389
# 9       9        XGB         0.497269
# 10      2        XGB         0.496036
# 11     21        XGB         0.495938
# 12     14        XGB         0.495882
# 13      4        XGB          0.49486
# 14     25        XGB         0.493543
# 15      1        XGB         0.489958
# 16     13        XGB          0.48895
# 17     22        XGB         0.488936
# 18     29        XGB         0.487647
# 19      0        XGB         0.485336
# 20     17        XGB         0.484244
# 21     11        XGB         0.484132
# 22     26        XGB          0.48409
# 23     16        XGB         0.480462
# 24      6        XGB         0.478235
# 25     28        XGB         0.473529
# 26      5        XGB         0.473445
# 27     18        XGB         0.472325
# 28     12        XGB          0.46986
# 29     20        XGB         0.467675
#
#                                                params iteration
# 0   {'min_child_weight': 1, 'max_depth': 9, 'learn...         3
# 1   {'min_child_weight': 1, 'max_depth': 7, 'learn...        24
# 2   {'min_child_weight': 1, 'max_depth': 9, 'learn...        23
# 3   {'min_child_weight': 1, 'max_depth': 7, 'learn...         7
# 4   {'min_child_weight': 1, 'max_depth': 9, 'learn...        19
# 5   {'min_child_weight': 1, 'max_depth': 10, 'lear...        27
# 6   {'min_child_weight': 1, 'max_depth': 10, 'lear...        10
# 7   {'min_child_weight': 1, 'max_depth': 9, 'learn...         8
# 8   {'min_child_weight': 1, 'max_depth': 7, 'learn...        15
# 9   {'min_child_weight': 1, 'max_depth': 7, 'learn...         9
# 10  {'min_child_weight': 1, 'max_depth': 9, 'learn...         2
# 11  {'min_child_weight': 1, 'max_depth': 7, 'learn...        21
# 12  {'min_child_weight': 1, 'max_depth': 3, 'learn...        14
# 13  {'min_child_weight': 1, 'max_depth': 7, 'learn...         4
# 14  {'min_child_weight': 1, 'max_depth': 10, 'lear...        25
# 15  {'min_child_weight': 1, 'max_depth': 3, 'learn...         1
# 16  {'min_child_weight': 1, 'max_depth': 10, 'lear...        13
# 17  {'min_child_weight': 1, 'max_depth': 9, 'learn...        22
# 18  {'min_child_weight': 1, 'max_depth': 3, 'learn...        29
# 19  {'min_child_weight': 1, 'max_depth': 10, 'lear...         0
# 20  {'min_child_weight': 1, 'max_depth': 10, 'lear...        17
# 21  {'min_child_weight': 1, 'max_depth': 3, 'learn...        11
# 22  {'min_child_weight': 1, 'max_depth': 3, 'learn...        26
# 23  {'min_child_weight': 1, 'max_depth': 3, 'learn...        16
# 24  {'min_child_weight': 1, 'max_depth': 3, 'learn...         6
# 25  {'min_child_weight': 1, 'max_depth': 3, 'learn...        28
# 26  {'min_child_weight': 1, 'max_depth': 3, 'learn...         5
# 27  {'min_child_weight': 1, 'max_depth': 3, 'learn...        18
# 28  {'min_child_weight': 1, 'max_depth': 3, 'learn...        12
# 29  {'min_child_weight': 1, 'max_depth': 3, 'learn...        20
# before walking around hyperparameters
# RF 0.5208263305322128
# XGB 0.5161904761904761
# first futher op
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 22
# new score: 0.543375350140056
# old score 0.5208263305322128
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 90
# new score: 0.543375350140056
# old score 0.543375350140056
# walking around  min_samples_split
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_split 10
# new score: 0.543375350140056
# old score 0.543375350140056
# walking around  min_samples_leaf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_leaf 6
# new score: 0.5480952380952381
# old score 0.543375350140056
# walking around  bootstrap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters bootstrap -9
# new score: 0.5480952380952381
# old score 0.5480952380952381
# second futher op
# walking around  min_child_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_child_weight 1
# new score: 0.5161904761904761
# old score 0.5161904761904761
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 18
# new score: 0.5162324929971989
# old score 0.5161904761904761
# walking around  learning_rate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters learning_rate 0.22500000000000003
# new score: 0.5101820728291317
# old score 0.5162324929971989
# walking around  reg_alpha
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_alpha 0.0
# new score: 0.5066806722689077
# old score 0.5162324929971989
# walking around  reg_lambda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_lambda 0.0
# new score: 0.5138375350140056
# old score 0.5162324929971989
# walking around  gamma
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters gamma 0.0022500000000000003
# new score: 0.5162184873949581
# old score 0.5162324929971989
# walking around  subsample
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters subsample 0.0
# new score: 0.5
# old score 0.5162324929971989
# walking around  colsample_bytree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters colsample_bytree 0.7874999999999999
# new score: 0.5197058823529412
# old score 0.5162324929971989
# walking around  scale_pos_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters scale_pos_weight 1
# new score: 0.5197058823529412
# old score 0.5197058823529412
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 96
# new score: 0.5220728291316526
# old score 0.5197058823529412
# calculating candidates on test set:
# 1. best tunned model based on cv validation
# 2. best tunned model based on minimun std
# 3. first model (with default parameters)
# 4. second model (with default parameters)
# expected_score_1,expected_score_2 0.54 0.5333333333333333
# expected_score_3,expected_score_4 0.5800000000000001 0.5466666666666666
# results_on_test_dict {1: 0.54, 2: 0.5333333333333333, 3: 0.5800000000000001, 4: 0.5466666666666666}
# selected_key 3
# l [None, 1.0, 0.5800000000000001, 'RF', None]
# saving scaler at /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_alpha_beta/eeg_alpha_beta_scaler.file
# Raw accuracy 0.5225175784599554
# ajusted_acc 0.5618073316283034
# selected_model: RF
# selected parameters: None
# score on test set of data: 0.5800000000000001
# Do not forget to see your report in: /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_alpha_beta
# --- 1308.5347874164581 seconds ---
# EEG 0.5800000000000001

# %%
experiment="delta"

run_experiment(experiment)
# Out:
# categorical_columns Index([], dtype='object')
#             0         1         2         3         4         5         6  \
# 0    0.710053  0.673089  0.896782  0.894461  0.803025  0.905243  0.851430
# 1    0.706104  0.699184  0.926069  0.924477  0.738980  0.919729  0.874682
# 2    0.774367  0.787049  0.919943  0.918186  0.774419  0.900345  0.899505
# 3    0.673525  0.638863  0.939211  0.936929  0.718696  0.949319  0.893448
# 4    0.755188  0.732251  0.925613  0.923918  0.778855  0.922397  0.877906
# ..        ...       ...       ...       ...       ...       ...       ...
# 990  0.768916  0.846233  0.965749  0.899205  0.807408  0.726484  0.845351
# 991  0.734641  0.810500  0.951981  0.869593  0.772897  0.771080  0.873558
# 992  0.710368  0.778035  0.932531  0.862491  0.801285  0.780717  0.848569
# 993  0.751620  0.817576  0.941502  0.886195  0.804049  0.775063  0.879014
# 994  0.744385  0.828992  0.948033  0.888940  0.815302  0.795131  0.894342
#
#             7         8         9  ...       101       102       103  \
# 0    0.776157  0.697889  0.902589  ...  0.774622  0.788456  0.830294
# 1    0.775566  0.754797  0.933571  ...  0.724117  0.651529  0.788593
# 2    0.824268  0.831262  0.932374  ...  0.832532  0.808870  0.828406
# 3    0.697747  0.623129  0.944686  ...  0.777034  0.711537  0.817681
# 4    0.831979  0.781081  0.931823  ...  0.771209  0.778099  0.816902
# ..        ...       ...       ...  ...       ...       ...       ...
# 990  0.775649  0.803043  0.951389  ...  0.954744  0.769338  0.855843
# 991  0.792669  0.771981  0.946248  ...  0.945367  0.748409  0.824006
# 992  0.764968  0.761452  0.925305  ...  0.927876  0.689381  0.793642
# 993  0.813823  0.778257  0.929710  ...  0.946810  0.753933  0.828135
# 994  0.808093  0.793333  0.944341  ...  0.943729  0.768249  0.848453
#
#           104       105       106       107       108       109  110
# 0    0.831809  0.763104  0.724282  0.794526  0.814169  0.794942  0.0
# 1    0.805144  0.771237  0.645808  0.753555  0.783362  0.725556  0.0
# 2    0.822836  0.768218  0.806882  0.866399  0.839726  0.779125  0.0
# 3    0.814847  0.797649  0.691532  0.804588  0.748032  0.686124  0.0
# 4    0.811028  0.731461  0.738376  0.828966  0.802972  0.757020  0.0
# ..        ...       ...       ...       ...       ...       ...  ...
# 990  0.630448  0.739897  0.694847  0.965886  0.636125  0.763023  0.0
# 991  0.668552  0.708509  0.655127  0.959453  0.664630  0.796511  0.0
# 992  0.716821  0.734602  0.679433  0.938932  0.678932  0.773936  0.0
# 993  0.627285  0.727498  0.680772  0.952821  0.629771  0.775656  0.0
# 994  0.620519  0.733728  0.666772  0.950227  0.619517  0.801778  0.0
#
# [995 rows x 111 columns]
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# Categorical data not detected.
# models ['RF', 'XGB']
# scores [0.4992997198879552, 0.4733893557422969]
# max_mean_cv_validation for no-clustering no-polynomial 0.4992997198879552
# models ['RF', 'XGB']
# scores [0.4731652661064426, 0.4946778711484594]
# max_mean_cv_validation for clustering 0.4946778711484594
# models ['RF', 'XGB']
# scores [0.4741036414565826, 0.4932072829131653]
# max_mean_cv_validation for for polynomial 0.4932072829131653
# score_mean_dict {0: 0.4992997198879552, 1: 0.4946778711484594, 2: 0.4932072829131653}
# temp_dic {'RF': 0.4992997198879552, 'XGB': 0.4733893557422969}
# selected second:  XGB 0.4733893557422969
# Starting hiper parameters tunning...
# hiper tunning results on RF
#      index name_model validation score  \
# 0      12         RF         0.562297
# 1      23         RF         0.517241
# 2      19         RF         0.517227
# 3      26         RF         0.512535
# 4       7         RF         0.508796
# 5      18         RF         0.507675
# 6      15         RF         0.507633
# 7      11         RF         0.506499
# 8       1         RF         0.506471
# 9      22         RF         0.505336
# 10      5         RF         0.504216
# 11     27         RF         0.503179
# 12     14         RF          0.50056
# 13      0         RF         0.498389
# 14     25         RF         0.498361
# 15     17         RF         0.498109
# 16     29         RF         0.496989
# 17     21         RF         0.485392
# 18     10         RF          0.48395
# 19     20         RF         0.482689
# 20     16         RF         0.481246
# 21      8         RF          0.48056
# 22      3         RF         0.476919
# 23     28         RF         0.476877
# 24     13         RF         0.475798
# 25      4         RF         0.474328
# 26      6         RF         0.473501
# 27      9         RF         0.468543
# 28     24         RF          0.46493
# 29      2         RF         0.454342
#
#                                                params iteration
# 0   {'n_estimators': 7, 'random_state': 10, 'max_f...        12
# 1   {'n_estimators': 18, 'random_state': 0, 'max_f...        23
# 2   {'n_estimators': 86, 'random_state': 10, 'max_...        19
# 3   {'n_estimators': 59, 'random_state': 42, 'max_...        26
# 4   {'n_estimators': 18, 'random_state': 0, 'max_f...         7
# 5   {'n_estimators': 76, 'random_state': 10, 'max_...        18
# 6   {'n_estimators': 79, 'random_state': 10, 'max_...        15
# 7   {'n_estimators': 93, 'random_state': 13, 'max_...        11
# 8   {'n_estimators': 69, 'random_state': 0, 'max_f...         1
# 9   {'n_estimators': 96, 'random_state': 0, 'max_f...        22
# 10  {'n_estimators': 82, 'random_state': 0, 'max_f...         5
# 11  {'n_estimators': 35, 'random_state': 42, 'max_...        27
# 12  {'n_estimators': 28, 'random_state': 10, 'max_...        14
# 13  {'n_estimators': 65, 'random_state': 10, 'max_...         0
# 14  {'n_estimators': 35, 'random_state': 13, 'max_...        25
# 15  {'n_estimators': 1, 'random_state': 13, 'max_f...        17
# 16  {'n_estimators': 100, 'random_state': 0, 'max_...        29
# 17  {'n_estimators': 79, 'random_state': 10, 'max_...        21
# 18  {'n_estimators': 65, 'random_state': 42, 'max_...        10
# 19  {'n_estimators': 45, 'random_state': 13, 'max_...        20
# 20  {'n_estimators': 4, 'random_state': 0, 'max_fe...        16
# 21  {'n_estimators': 76, 'random_state': 42, 'max_...         8
# 22  {'n_estimators': 55, 'random_state': 42, 'max_...         3
# 23  {'n_estimators': 65, 'random_state': 0, 'max_f...        28
# 24  {'n_estimators': 11, 'random_state': 10, 'max_...        13
# 25  {'n_estimators': 100, 'random_state': 10, 'max...         4
# 26  {'n_estimators': 52, 'random_state': 10, 'max_...         6
# 27  {'n_estimators': 55, 'random_state': 0, 'max_f...         9
# 28  {'n_estimators': 100, 'random_state': 13, 'max...        24
# 29  {'n_estimators': 55, 'random_state': 10, 'max_...         2
# hiper tunning results on XGB
#      index name_model validation score  \
# 0       6        XGB         0.504048
# 1      15        XGB         0.501611
# 2       4        XGB         0.493459
# 3      13        XGB         0.491176
# 4       3        XGB         0.488739
# 5      20        XGB         0.487731
# 6       9        XGB         0.487493
# 7       2        XGB         0.486401
# 8      29        XGB         0.482773
# 9      28        XGB         0.481653
# 10     10        XGB         0.481597
# 11      0        XGB         0.481485
# 12      1        XGB         0.481485
# 13     17        XGB          0.48049
# 14     18        XGB          0.48028
# 15     19        XGB         0.479328
# 16     26        XGB         0.479076
# 17      5        XGB         0.478067
# 18     22        XGB         0.475868
# 19     24        XGB         0.474426
# 20     16        XGB         0.472143
# 21     11        XGB         0.470966
# 22     21        XGB         0.469608
# 23     14        XGB         0.468585
# 24      7        XGB         0.468557
# 25     27        XGB         0.468529
# 26     25        XGB         0.466232
# 27      8        XGB         0.464986
# 28     12        XGB         0.447283
# 29     23        XGB          0.44479
#
#                                                params iteration
# 0   {'min_child_weight': 1, 'max_depth': 3, 'learn...         6
# 1   {'min_child_weight': 1, 'max_depth': 9, 'learn...        15
# 2   {'min_child_weight': 1, 'max_depth': 3, 'learn...         4
# 3   {'min_child_weight': 1, 'max_depth': 3, 'learn...        13
# 4   {'min_child_weight': 1, 'max_depth': 3, 'learn...         3
# 5   {'min_child_weight': 1, 'max_depth': 3, 'learn...        20
# 6   {'min_child_weight': 1, 'max_depth': 7, 'learn...         9
# 7   {'min_child_weight': 1, 'max_depth': 3, 'learn...         2
# 8   {'min_child_weight': 1, 'max_depth': 9, 'learn...        29
# 9   {'min_child_weight': 1, 'max_depth': 7, 'learn...        28
# 10  {'min_child_weight': 1, 'max_depth': 3, 'learn...        10
# 11  {'min_child_weight': 1, 'max_depth': 7, 'learn...         0
# 12  {'min_child_weight': 1, 'max_depth': 9, 'learn...         1
# 13  {'min_child_weight': 1, 'max_depth': 3, 'learn...        17
# 14  {'min_child_weight': 1, 'max_depth': 10, 'lear...        18
# 15  {'min_child_weight': 1, 'max_depth': 3, 'learn...        19
# 16  {'min_child_weight': 1, 'max_depth': 7, 'learn...        26
# 17  {'min_child_weight': 1, 'max_depth': 10, 'lear...         5
# 18  {'min_child_weight': 1, 'max_depth': 9, 'learn...        22
# 19  {'min_child_weight': 1, 'max_depth': 7, 'learn...        24
# 20  {'min_child_weight': 1, 'max_depth': 7, 'learn...        16
# 21  {'min_child_weight': 1, 'max_depth': 10, 'lear...        11
# 22  {'min_child_weight': 1, 'max_depth': 10, 'lear...        21
# 23  {'min_child_weight': 1, 'max_depth': 9, 'learn...        14
# 24  {'min_child_weight': 1, 'max_depth': 9, 'learn...         7
# 25  {'min_child_weight': 1, 'max_depth': 9, 'learn...        27
# 26  {'min_child_weight': 1, 'max_depth': 9, 'learn...        25
# 27  {'min_child_weight': 1, 'max_depth': 10, 'lear...         8
# 28  {'min_child_weight': 1, 'max_depth': 7, 'learn...        12
# 29  {'min_child_weight': 1, 'max_depth': 10, 'lear...        23
# before walking around hyperparameters
# RF 0.5622969187675071
# XGB 0.5040476190476191
# first futher op
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 3
# new score: 0.5729411764705883
# old score 0.5622969187675071
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 60
# new score: 0.5729411764705883
# old score 0.5729411764705883
# walking around  min_samples_split
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_split 2
# new score: 0.5729411764705883
# old score 0.5729411764705883
# walking around  min_samples_leaf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_leaf 2
# new score: 0.57609243697479
# old score 0.5729411764705883
# walking around  bootstrap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters bootstrap 0
# new score: 0.57609243697479
# old score 0.57609243697479
# second futher op
# walking around  min_child_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_child_weight 0
# new score: 0.5276190476190475
# old score 0.5040476190476191
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 3
# new score: 0.5276190476190475
# old score 0.5276190476190475
# walking around  learning_rate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters learning_rate 0.0675
# new score: 0.5170028011204482
# old score 0.5276190476190475
# walking around  reg_alpha
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_alpha 0.01875
# new score: 0.5288375350140055
# old score 0.5276190476190475
# walking around  reg_lambda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_lambda 1.6875
# new score: 0.5242296918767508
# old score 0.5288375350140055
# walking around  gamma
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters gamma 0.0
# new score: 0.5288375350140055
# old score 0.5288375350140055
# walking around  subsample
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters subsample 0.0
# new score: 0.5
# old score 0.5288375350140055
# walking around  colsample_bytree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters colsample_bytree 0.675
# new score: 0.48649859943977586
# old score 0.5288375350140055
# walking around  scale_pos_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters scale_pos_weight 1
# new score: 0.5288375350140055
# old score 0.5288375350140055
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 30
# new score: 0.5299159663865546
# old score 0.5288375350140055
# calculating candidates on test set:
# 1. best tunned model based on cv validation
# 2. best tunned model based on minimun std
# 3. first model (with default parameters)
# 4. second model (with default parameters)
# expected_score_1,expected_score_2 0.48000000000000004 0.5666666666666667
# expected_score_3,expected_score_4 0.5466666666666666 0.6133333333333333
# results_on_test_dict {1: 0.48000000000000004, 2: 0.5666666666666667, 3: 0.5466666666666666, 4: 0.6133333333333333}
# selected_key 4
# l [None, 0.9928571428571429, 0.6133333333333333, 'XGB', None]
# saving scaler at /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_delta/eeg_delta_scaler.file
# Raw accuracy 0.5869662150574515
# ajusted_acc 0.6346973572037511
# selected_model: XGB
# selected parameters: None
# score on test set of data: 0.6133333333333333
# Do not forget to see your report in: /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_delta
# --- 593.3148634433746 seconds ---
# EEG 0.6133333333333333

# %%
#experiment="entropy"

#run_experiment(experiment)

# %%
#experiment="entropy_delta_theta"

#run_experiment(experiment)
