# %%
import os
import sys

sys.path.append("/home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/")
sys.path.append("/home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/Classes/")
sys.path.append("/home/gari/Desktop/master_tesis_v2/")

from OFHandlers import OFHandlers as OFH
import CoreML
import pandas as pd
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import SelectKBest, chi2
# Out:
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.bagging module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/gari/anaconda3/envs/EEG/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
def run_experiment(experiment):
    #experiment="_entropy_delta_theta"
    data_co="/home/gari/Desktop/master_tesis_v2/Data/Datasets_"
    data_origin=data_co+experiment+"/prepared_train_data_set.file"
    
    data_test_path=data_co+experiment+"/prepared_test_data_set.file"


    note_exp=experiment

    data=OFH.load_object(data_origin)
    score_1=CoreML.core_diagnosis(data_origin=data,
                      data_origin_string="object_dataframe",
                      name="/eeg_"+experiment,
                      string_metric="roc_auc_score",
                      number_of_clusters=200,
                      hiper_tunning_iters=30,
                      futher_op_boo=True,
                      balance_train=False,
                      clustering=True,
                      polynomial=True,
                      test_size=0.2,
                      path_to_test=data_test_path,
                      note_exp=note_exp)
    print("EEG",score_1)

# %%
experiment="all_power_bands"

run_experiment(experiment)
# Out:
# categorical_columns Index([], dtype='object')
#             0         1         2         3         4         5         6  \
# 0    0.710053  0.154375  0.112361  0.023211  0.673089  0.163235  0.135055
# 1    0.706104  0.137911  0.133896  0.022090  0.699184  0.127034  0.147558
# 2    0.774367  0.129987  0.080810  0.014836  0.787049  0.104337  0.092860
# 3    0.673525  0.160555  0.139623  0.026297  0.638863  0.149104  0.182793
# 4    0.755188  0.128808  0.099585  0.016419  0.732251  0.128041  0.120492
# ..        ...       ...       ...       ...       ...       ...       ...
# 990  0.768916  0.142740  0.068189  0.020155  0.846233  0.086003  0.052153
# 991  0.734641  0.179887  0.063818  0.021654  0.810500  0.129774  0.042770
# 992  0.710368  0.182840  0.078484  0.028307  0.778035  0.145555  0.051657
# 993  0.751620  0.144237  0.079804  0.024340  0.817576  0.103941  0.054841
# 994  0.744385  0.131744  0.098037  0.025834  0.828992  0.090900  0.058867
#
#             7         8         9  ...       431       432       433  \
# 0    0.028621  0.896782  0.062786  ...  0.016562  0.814169  0.094598
# 1    0.026224  0.926069  0.040975  ...  0.015842  0.783362  0.093159
# 2    0.015754  0.919943  0.058315  ...  0.008639  0.839726  0.083272
# 3    0.029241  0.939211  0.031990  ...  0.013694  0.748032  0.106801
# 4    0.019216  0.925613  0.046021  ...  0.010878  0.802972  0.099438
# ..        ...       ...       ...  ...       ...       ...       ...
# 990  0.015612  0.965749  0.020573  ...  0.005187  0.636125  0.218136
# 991  0.016956  0.951981  0.029441  ...  0.005112  0.664630  0.225804
# 992  0.024753  0.932531  0.038837  ...  0.011159  0.678932  0.211379
# 993  0.023641  0.941502  0.035951  ...  0.007173  0.629771  0.218417
# 994  0.021242  0.948033  0.030925  ...  0.006191  0.619517  0.226447
#
#           434       435       436       437       438       439  440
# 0    0.073320  0.017913  0.794942  0.104656  0.079279  0.021124  0.0
# 1    0.104936  0.018543  0.725556  0.123757  0.127691  0.022997  0.0
# 2    0.065236  0.011765  0.779125  0.124423  0.079929  0.016523  0.0
# 3    0.128119  0.017048  0.686124  0.134365  0.158061  0.021451  0.0
# 4    0.084324  0.013267  0.757020  0.127743  0.097547  0.017690  0.0
# ..        ...       ...       ...       ...       ...       ...  ...
# 990  0.116975  0.028764  0.763023  0.148261  0.070648  0.018068  0.0
# 991  0.084983  0.024583  0.796511  0.138618  0.049400  0.015472  0.0
# 992  0.080067  0.029623  0.773936  0.154297  0.049788  0.021979  0.0
# 993  0.110171  0.041641  0.775656  0.139883  0.060904  0.023557  0.0
# 994  0.118564  0.035472  0.801778  0.132214  0.048184  0.017824  0.0
#
# [995 rows x 441 columns]
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# Categorical data not detected.
# models ['RF', 'XGB']
# scores [0.44495798319327723, 0.4795378151260504]
# max_mean_cv_validation for no-clustering no-polynomial 0.4795378151260504
# models ['RF', 'XGB']
# scores [0.44602240896358547, 0.4700420168067227]
# max_mean_cv_validation for clustering 0.4700420168067227
# models ['RF', 'XGB']
# scores [0.4935434173669468, 0.4852801120448179]
# max_mean_cv_validation for for polynomial 0.4935434173669468
# score_mean_dict {0: 0.4795378151260504, 1: 0.4700420168067227, 2: 0.4935434173669468}
# temp_dic {'RF': 0.4935434173669468, 'XGB': 0.4852801120448179}
# selected second:  XGB 0.4852801120448179
# Starting hiper parameters tunning...
# hiper tunning results on RF
#      index name_model validation score  \
# 0      16         RF          0.52063
# 1      10         RF         0.511359
# 2      25         RF          0.50542
# 3       3         RF          0.50542
# 4      24         RF          0.50528
# 5      17         RF         0.504174
# 6      28         RF         0.503053
# 7      21         RF         0.503011
# 8       5         RF         0.500742
# 9       9         RF          0.50063
# 10      0         RF         0.499384
# 11      2         RF         0.495966
# 12      1         RF         0.495798
# 13     20         RF         0.494594
# 14     13         RF          0.49458
# 15     26         RF         0.493571
# 16     19         RF         0.493557
# 17      7         RF         0.492241
# 18     12         RF         0.492185
# 19     14         RF          0.48881
# 20     18         RF         0.487507
# 21     23         RF         0.486471
# 22     15         RF         0.486331
# 23      4         RF          0.48521
# 24      6         RF         0.485182
# 25     27         RF         0.485168
# 26     11         RF          0.48402
# 27      8         RF         0.478277
# 28     29         RF         0.472157
# 29     22         RF         0.469902
#
#                                                params iteration
# 0   {'n_estimators': 45, 'random_state': 42, 'max_...        16
# 1   {'n_estimators': 93, 'random_state': 13, 'max_...        10
# 2   {'n_estimators': 31, 'random_state': 0, 'max_f...        25
# 3   {'n_estimators': 62, 'random_state': 0, 'max_f...         3
# 4   {'n_estimators': 38, 'random_state': 0, 'max_f...        24
# 5   {'n_estimators': 24, 'random_state': 42, 'max_...        17
# 6   {'n_estimators': 86, 'random_state': 10, 'max_...        28
# 7   {'n_estimators': 38, 'random_state': 10, 'max_...        21
# 8   {'n_estimators': 14, 'random_state': 10, 'max_...         5
# 9   {'n_estimators': 89, 'random_state': 0, 'max_f...         9
# 10  {'n_estimators': 45, 'random_state': 0, 'max_f...         0
# 11  {'n_estimators': 65, 'random_state': 10, 'max_...         2
# 12  {'n_estimators': 18, 'random_state': 13, 'max_...         1
# 13  {'n_estimators': 35, 'random_state': 13, 'max_...        20
# 14  {'n_estimators': 24, 'random_state': 42, 'max_...        13
# 15  {'n_estimators': 52, 'random_state': 13, 'max_...        26
# 16  {'n_estimators': 7, 'random_state': 10, 'max_f...        19
# 17  {'n_estimators': 11, 'random_state': 42, 'max_...         7
# 18  {'n_estimators': 41, 'random_state': 0, 'max_f...        12
# 19  {'n_estimators': 72, 'random_state': 13, 'max_...        14
# 20  {'n_estimators': 38, 'random_state': 13, 'max_...        18
# 21  {'n_estimators': 76, 'random_state': 10, 'max_...        23
# 22  {'n_estimators': 24, 'random_state': 10, 'max_...        15
# 23  {'n_estimators': 72, 'random_state': 10, 'max_...         4
# 24  {'n_estimators': 24, 'random_state': 0, 'max_f...         6
# 25  {'n_estimators': 21, 'random_state': 0, 'max_f...        27
# 26  {'n_estimators': 93, 'random_state': 10, 'max_...        11
# 27  {'n_estimators': 45, 'random_state': 42, 'max_...         8
# 28  {'n_estimators': 31, 'random_state': 42, 'max_...        29
# 29  {'n_estimators': 31, 'random_state': 42, 'max_...        22
# hiper tunning results on XGB
#      index name_model validation score  \
# 0       8        XGB         0.518571
# 1      15        XGB         0.516078
# 2      14        XGB         0.515042
# 3       9        XGB         0.513683
# 4      23        XGB         0.511387
# 5       2        XGB         0.511218
# 6      20        XGB         0.509062
# 7      10        XGB         0.508978
# 8      18        XGB         0.506709
# 9       4        XGB         0.505462
# 10      3        XGB         0.505448
# 11     24        XGB         0.505406
# 12      1        XGB         0.505238
# 13     27        XGB         0.500686
# 14     28        XGB          0.50063
# 15     17        XGB         0.495938
# 16     29        XGB         0.494832
# 17     21        XGB         0.494776
# 18     12        XGB         0.494706
# 19     19        XGB         0.492465
# 20     13        XGB          0.49119
# 21     25        XGB         0.491176
# 22      6        XGB         0.491176
# 23      0        XGB         0.491148
# 24     16        XGB         0.490084
# 25      5        XGB         0.487675
# 26     22        XGB         0.486499
# 27      7        XGB         0.485028
# 28     26        XGB          0.48416
# 29     11        XGB          0.47944
#
#                                                params iteration
# 0   {'min_child_weight': 1, 'max_depth': 7, 'learn...         8
# 1   {'min_child_weight': 1, 'max_depth': 9, 'learn...        15
# 2   {'min_child_weight': 1, 'max_depth': 9, 'learn...        14
# 3   {'min_child_weight': 1, 'max_depth': 9, 'learn...         9
# 4   {'min_child_weight': 1, 'max_depth': 7, 'learn...        23
# 5   {'min_child_weight': 1, 'max_depth': 10, 'lear...         2
# 6   {'min_child_weight': 1, 'max_depth': 10, 'lear...        20
# 7   {'min_child_weight': 1, 'max_depth': 7, 'learn...        10
# 8   {'min_child_weight': 1, 'max_depth': 7, 'learn...        18
# 9   {'min_child_weight': 1, 'max_depth': 9, 'learn...         4
# 10  {'min_child_weight': 1, 'max_depth': 9, 'learn...         3
# 11  {'min_child_weight': 1, 'max_depth': 9, 'learn...        24
# 12  {'min_child_weight': 1, 'max_depth': 3, 'learn...         1
# 13  {'min_child_weight': 1, 'max_depth': 9, 'learn...        27
# 14  {'min_child_weight': 1, 'max_depth': 3, 'learn...        28
# 15  {'min_child_weight': 1, 'max_depth': 7, 'learn...        17
# 16  {'min_child_weight': 1, 'max_depth': 10, 'lear...        29
# 17  {'min_child_weight': 1, 'max_depth': 7, 'learn...        21
# 18  {'min_child_weight': 1, 'max_depth': 3, 'learn...        12
# 19  {'min_child_weight': 1, 'max_depth': 9, 'learn...        19
# 20  {'min_child_weight': 1, 'max_depth': 7, 'learn...        13
# 21  {'min_child_weight': 1, 'max_depth': 9, 'learn...        25
# 22  {'min_child_weight': 1, 'max_depth': 3, 'learn...         6
# 23  {'min_child_weight': 1, 'max_depth': 3, 'learn...         0
# 24  {'min_child_weight': 1, 'max_depth': 7, 'learn...        16
# 25  {'min_child_weight': 1, 'max_depth': 3, 'learn...         5
# 26  {'min_child_weight': 1, 'max_depth': 3, 'learn...        22
# 27  {'min_child_weight': 1, 'max_depth': 3, 'learn...         7
# 28  {'min_child_weight': 1, 'max_depth': 7, 'learn...        26
# 29  {'min_child_weight': 1, 'max_depth': 3, 'learn...        11
# before walking around hyperparameters
# RF 0.5206302521008404
# XGB 0.5185714285714285
# first futher op
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 25
# new score: 0.5491176470588235
# old score 0.5206302521008404
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 100
# new score: 0.5491176470588235
# old score 0.5491176470588235
# walking around  min_samples_split
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_split 2
# new score: 0.5491176470588235
# old score 0.5491176470588235
# walking around  min_samples_leaf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_leaf 4
# new score: 0.5491176470588235
# old score 0.5491176470588235
# walking around  bootstrap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters bootstrap -9
# new score: 0.5491176470588235
# old score 0.5491176470588235
# second futher op
# walking around  min_child_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_child_weight 1
# new score: 0.5185714285714285
# old score 0.5185714285714285
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 11
# new score: 0.5208543417366946
# old score 0.5185714285714285
# walking around  learning_rate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters learning_rate 0.30000000000000004
# new score: 0.5232212885154063
# old score 0.5208543417366946
# walking around  reg_alpha
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_alpha 0.03
# new score: 0.523235294117647
# old score 0.5232212885154063
# walking around  reg_lambda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_lambda 1
# new score: 0.523235294117647
# old score 0.523235294117647
# walking around  gamma
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters gamma 0.0022500000000000003
# new score: 0.523235294117647
# old score 0.523235294117647
# walking around  subsample
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters subsample 0.0
# new score: 0.5
# old score 0.523235294117647
# walking around  colsample_bytree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters colsample_bytree 0.675
# new score: 0.4970588235294118
# old score 0.523235294117647
# walking around  scale_pos_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters scale_pos_weight 1
# new score: 0.523235294117647
# old score 0.523235294117647
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 196
# new score: 0.523235294117647
# old score 0.523235294117647
# calculating candidates on test set:
# 1. best tunned model based on cv validation
# 2. best tunned model based on minimun std
# 3. first model (with default parameters)
# 4. second model (with default parameters)
# expected_score_1,expected_score_2 0.52 0.5800000000000001
# expected_score_3,expected_score_4 0.5866666666666667 0.54
# results_on_test_dict {1: 0.52, 2: 0.5800000000000001, 3: 0.5866666666666667, 4: 0.54}
# selected_key 3
# l [None, 1.0, 0.5866666666666667, 'RF', None]
# saving scaler at /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_all_power_bands/eeg_all_power_bands_scaler.file
# Raw accuracy 0.5373006345395301
# ajusted_acc 0.5618073316283034
# selected_model: RF
# selected parameters: None
# score on test set of data: 0.5866666666666667
# Do not forget to see your report in: /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_all_power_bands
# --- 1722.4972784519196 seconds ---
# EEG 0.5866666666666667

# %%
experiment="delta_theta"

run_experiment(experiment)
# Out:
# categorical_columns Index([], dtype='object')
#             0         1         2         3         4         5         6  \
# 0    0.710053  0.154375  0.673089  0.163235  0.896782  0.062786  0.894461
# 1    0.706104  0.137911  0.699184  0.127034  0.926069  0.040975  0.924477
# 2    0.774367  0.129987  0.787049  0.104337  0.919943  0.058315  0.918186
# 3    0.673525  0.160555  0.638863  0.149104  0.939211  0.031990  0.936929
# 4    0.755188  0.128808  0.732251  0.128041  0.925613  0.046021  0.923918
# ..        ...       ...       ...       ...       ...       ...       ...
# 990  0.768916  0.142740  0.846233  0.086003  0.965749  0.020573  0.899205
# 991  0.734641  0.179887  0.810500  0.129774  0.951981  0.029441  0.869593
# 992  0.710368  0.182840  0.778035  0.145555  0.932531  0.038837  0.862491
# 993  0.751620  0.144237  0.817576  0.103941  0.941502  0.035951  0.886195
# 994  0.744385  0.131744  0.828992  0.090900  0.948033  0.030925  0.888940
#
#             7         8         9  ...       211       212       213  \
# 0    0.064521  0.803025  0.095103  ...  0.118238  0.724282  0.143397
# 1    0.040696  0.738980  0.129414  ...  0.106026  0.645808  0.158099
# 2    0.057361  0.774419  0.130173  ...  0.139494  0.806882  0.099338
# 3    0.031391  0.718696  0.121402  ...  0.108235  0.691532  0.159799
# 4    0.045144  0.778855  0.116972  ...  0.133165  0.738376  0.127792
# ..        ...       ...       ...  ...       ...       ...       ...
# 990  0.047060  0.807408  0.090060  ...  0.162678  0.694847  0.194484
# 991  0.083203  0.772897  0.147869  ...  0.197470  0.655127  0.234523
# 992  0.086163  0.801285  0.131209  ...  0.164059  0.679433  0.200112
# 993  0.065934  0.804049  0.112320  ...  0.162366  0.680772  0.191570
# 994  0.057172  0.815302  0.096264  ...  0.128732  0.666772  0.169091
#
#           214       215       216       217       218       219  220
# 0    0.794526  0.119187  0.814169  0.094598  0.794942  0.104656  0.0
# 1    0.753555  0.114119  0.783362  0.093159  0.725556  0.123757  0.0
# 2    0.866399  0.076496  0.839726  0.083272  0.779125  0.124423  0.0
# 3    0.804588  0.096159  0.748032  0.106801  0.686124  0.134365  0.0
# 4    0.828966  0.087832  0.802972  0.099438  0.757020  0.127743  0.0
# ..        ...       ...       ...       ...       ...       ...  ...
# 990  0.965886  0.018862  0.636125  0.218136  0.763023  0.148261  0.0
# 991  0.959453  0.023325  0.664630  0.225804  0.796511  0.138618  0.0
# 992  0.938932  0.031232  0.678932  0.211379  0.773936  0.154297  0.0
# 993  0.952821  0.029409  0.629771  0.218417  0.775656  0.139883  0.0
# 994  0.950227  0.030943  0.619517  0.226447  0.801778  0.132214  0.0
#
# [995 rows x 221 columns]
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# Categorical data not detected.
# models ['RF', 'XGB']
# scores [0.5099019607843137, 0.4818767507002802]
# max_mean_cv_validation for no-clustering no-polynomial 0.5099019607843137
# models ['RF', 'XGB']
# scores [0.4590616246498599, 0.4734873949579832]
# max_mean_cv_validation for clustering 0.4734873949579832
# models ['RF', 'XGB']
# scores [0.5001820728291316, 0.5097198879551821]
# max_mean_cv_validation for for polynomial 0.5097198879551821
# score_mean_dict {0: 0.5099019607843137, 1: 0.4734873949579832, 2: 0.5097198879551821}
# temp_dic {'RF': 0.5099019607843137, 'XGB': 0.4818767507002802}
# selected second:  XGB 0.4818767507002802
# Starting hiper parameters tunning...
# hiper tunning results on RF
#      index name_model validation score  \
# 0       0         RF         0.545546
# 1      27         RF         0.533599
# 2       4         RF         0.532437
# 3      22         RF         0.525294
# 4      24         RF         0.524258
# 5      12         RF         0.524062
# 6       9         RF         0.519286
# 7      26         RF         0.518375
# 8       5         RF         0.518151
# 9      11         RF         0.517087
# 10     29         RF         0.516835
# 11     23         RF         0.515868
# 12     25         RF         0.513529
# 13      2         RF         0.512423
# 14      3         RF         0.511064
# 15     13         RF         0.507241
# 16     20         RF         0.506401
# 17     15         RF         0.506401
# 18     10         RF         0.504006
# 19      1         RF         0.500462
# 20     28         RF         0.500434
# 21     17         RF         0.500392
# 22     18         RF           0.4993
# 23     14         RF         0.498151
# 24      8         RF         0.498137
# 25      7         RF         0.498011
# 26     16         RF         0.492269
# 27     21         RF         0.489846
# 28      6         RF         0.481457
# 29     19         RF         0.480308
#
#                                                params iteration
# 0   {'n_estimators': 7, 'random_state': 42, 'max_f...         0
# 1   {'n_estimators': 76, 'random_state': 0, 'max_f...        27
# 2   {'n_estimators': 100, 'random_state': 0, 'max_...         4
# 3   {'n_estimators': 65, 'random_state': 0, 'max_f...        22
# 4   {'n_estimators': 21, 'random_state': 0, 'max_f...        24
# 5   {'n_estimators': 31, 'random_state': 13, 'max_...        12
# 6   {'n_estimators': 31, 'random_state': 10, 'max_...         9
# 7   {'n_estimators': 65, 'random_state': 13, 'max_...        26
# 8   {'n_estimators': 62, 'random_state': 10, 'max_...         5
# 9   {'n_estimators': 35, 'random_state': 42, 'max_...        11
# 10  {'n_estimators': 4, 'random_state': 0, 'max_fe...        29
# 11  {'n_estimators': 76, 'random_state': 0, 'max_f...        23
# 12  {'n_estimators': 35, 'random_state': 0, 'max_f...        25
# 13  {'n_estimators': 69, 'random_state': 13, 'max_...         2
# 14  {'n_estimators': 86, 'random_state': 0, 'max_f...         3
# 15  {'n_estimators': 4, 'random_state': 0, 'max_fe...        13
# 16  {'n_estimators': 79, 'random_state': 0, 'max_f...        20
# 17  {'n_estimators': 79, 'random_state': 13, 'max_...        15
# 18  {'n_estimators': 72, 'random_state': 13, 'max_...        10
# 19  {'n_estimators': 69, 'random_state': 10, 'max_...         1
# 20  {'n_estimators': 69, 'random_state': 13, 'max_...        28
# 21  {'n_estimators': 76, 'random_state': 13, 'max_...        17
# 22  {'n_estimators': 41, 'random_state': 0, 'max_f...        18
# 23  {'n_estimators': 59, 'random_state': 13, 'max_...        14
# 24  {'n_estimators': 96, 'random_state': 13, 'max_...         8
# 25  {'n_estimators': 100, 'random_state': 0, 'max_...         7
# 26  {'n_estimators': 69, 'random_state': 0, 'max_f...        16
# 27  {'n_estimators': 96, 'random_state': 10, 'max_...        21
# 28  {'n_estimators': 21, 'random_state': 13, 'max_...         6
# 29  {'n_estimators': 18, 'random_state': 13, 'max_...        19
# hiper tunning results on XGB
#      index name_model validation score  \
# 0       9        XGB         0.518333
# 1      22        XGB         0.508852
# 2      17        XGB         0.506471
# 3      11        XGB         0.505322
# 4      28        XGB         0.503039
# 5       5        XGB         0.502913
# 6      23        XGB          0.50063
# 7      18        XGB         0.500574
# 8      29        XGB         0.498347
# 9       8        XGB         0.497129
# 10     25        XGB         0.495938
# 11     21        XGB         0.495924
# 12     16        XGB         0.493473
# 13     26        XGB         0.492353
# 14      2        XGB         0.491232
# 15     12        XGB         0.489986
# 16     15        XGB         0.488824
# 17     24        XGB         0.487689
# 18     13        XGB         0.487535
# 19     10        XGB         0.484146
# 20      1        XGB         0.482927
# 21     19        XGB         0.482885
# 22      4        XGB         0.481793
# 23      3        XGB         0.481597
# 24      6        XGB          0.48063
# 25     14        XGB         0.477031
# 26      7        XGB         0.475896
# 27     27        XGB         0.475728
# 28      0        XGB         0.472171
# 29     20        XGB         0.468683
#
#                                                params iteration
# 0   {'min_child_weight': 1, 'max_depth': 9, 'learn...         9
# 1   {'min_child_weight': 1, 'max_depth': 10, 'lear...        22
# 2   {'min_child_weight': 1, 'max_depth': 7, 'learn...        17
# 3   {'min_child_weight': 1, 'max_depth': 3, 'learn...        11
# 4   {'min_child_weight': 1, 'max_depth': 9, 'learn...        28
# 5   {'min_child_weight': 1, 'max_depth': 9, 'learn...         5
# 6   {'min_child_weight': 1, 'max_depth': 3, 'learn...        23
# 7   {'min_child_weight': 1, 'max_depth': 9, 'learn...        18
# 8   {'min_child_weight': 1, 'max_depth': 3, 'learn...        29
# 9   {'min_child_weight': 1, 'max_depth': 10, 'lear...         8
# 10  {'min_child_weight': 1, 'max_depth': 9, 'learn...        25
# 11  {'min_child_weight': 1, 'max_depth': 3, 'learn...        21
# 12  {'min_child_weight': 1, 'max_depth': 9, 'learn...        16
# 13  {'min_child_weight': 1, 'max_depth': 3, 'learn...        26
# 14  {'min_child_weight': 1, 'max_depth': 9, 'learn...         2
# 15  {'min_child_weight': 1, 'max_depth': 7, 'learn...        12
# 16  {'min_child_weight': 1, 'max_depth': 7, 'learn...        15
# 17  {'min_child_weight': 1, 'max_depth': 10, 'lear...        24
# 18  {'min_child_weight': 1, 'max_depth': 9, 'learn...        13
# 19  {'min_child_weight': 1, 'max_depth': 9, 'learn...        10
# 20  {'min_child_weight': 1, 'max_depth': 10, 'lear...         1
# 21  {'min_child_weight': 1, 'max_depth': 7, 'learn...        19
# 22  {'min_child_weight': 1, 'max_depth': 10, 'lear...         4
# 23  {'min_child_weight': 1, 'max_depth': 9, 'learn...         3
# 24  {'min_child_weight': 1, 'max_depth': 10, 'lear...         6
# 25  {'min_child_weight': 1, 'max_depth': 7, 'learn...        14
# 26  {'min_child_weight': 1, 'max_depth': 10, 'lear...         7
# 27  {'min_child_weight': 1, 'max_depth': 9, 'learn...        27
# 28  {'min_child_weight': 1, 'max_depth': 7, 'learn...         0
# 29  {'min_child_weight': 1, 'max_depth': 9, 'learn...        20
# before walking around hyperparameters
# RF 0.5455462184873949
# XGB 0.5183333333333333
# first futher op
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 11
# new score: 0.5478711484593838
# old score 0.5455462184873949
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 20
# new score: 0.5478711484593838
# old score 0.5478711484593838
# walking around  min_samples_split
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_split 2
# new score: 0.5478711484593838
# old score 0.5478711484593838
# walking around  min_samples_leaf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_leaf 1
# new score: 0.5525910364145659
# old score 0.5478711484593838
# walking around  bootstrap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters bootstrap -9
# new score: 0.5525910364145659
# old score 0.5525910364145659
# second futher op
# walking around  min_child_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_child_weight 1
# new score: 0.5183333333333333
# old score 0.5183333333333333
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 5
# new score: 0.5279131652661064
# old score 0.5183333333333333
# walking around  learning_rate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters learning_rate 1.9500000000000002
# new score: 0.5489495798319327
# old score 0.5279131652661064
# walking around  reg_alpha
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_alpha 0.0225
# new score: 0.5642577030812325
# old score 0.5489495798319327
# walking around  reg_lambda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_lambda 4.5
# new score: 0.5173389355742297
# old score 0.5642577030812325
# walking around  gamma
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters gamma 0.0225
# new score: 0.5701820728291317
# old score 0.5642577030812325
# walking around  subsample
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters subsample 0.3375
# new score: 0.5064565826330532
# old score 0.5701820728291317
# walking around  colsample_bytree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters colsample_bytree 0.26249999999999996
# new score: 0.5218487394957982
# old score 0.5701820728291317
# walking around  scale_pos_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters scale_pos_weight 1
# new score: 0.5701820728291317
# old score 0.5701820728291317
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 476
# new score: 0.5725770308123249
# old score 0.5701820728291317
# calculating candidates on test set:
# 1. best tunned model based on cv validation
# 2. best tunned model based on minimun std
# 3. first model (with default parameters)
# 4. second model (with default parameters)
# expected_score_1,expected_score_2 0.5466666666666666 0.44666666666666666
# expected_score_3,expected_score_4 0.5933333333333333 0.58
# results_on_test_dict {1: 0.5466666666666666, 2: 0.44666666666666666, 3: 0.5933333333333333, 4: 0.58}
# selected_key 3
# l [None, 1.0, 0.5933333333333333, 'RF', None]
# saving scaler at /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_delta_theta/eeg_delta_theta_scaler.file
# Raw accuracy 0.5399588406791288
# ajusted_acc 0.5835464620630861
# selected_model: RF
# selected parameters: None
# score on test set of data: 0.5933333333333333
# Do not forget to see your report in: /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_delta_theta
# --- 1874.385066986084 seconds ---
# EEG 0.5933333333333333

# %%
experiment="alpha_beta"

run_experiment(experiment)
# Out:
# categorical_columns Index([], dtype='object')
#             0         1         2         3         4         5         6  \
# 0    0.112361  0.023211  0.135055  0.028621  0.029584  0.010847  0.030005
# 1    0.133896  0.022090  0.147558  0.026224  0.028139  0.004817  0.029635
# 2    0.080810  0.014836  0.092860  0.015754  0.017251  0.004491  0.019462
# 3    0.139623  0.026297  0.182793  0.029241  0.023117  0.005682  0.025782
# 4    0.099585  0.016419  0.120492  0.019216  0.021477  0.006889  0.023565
# ..        ...       ...       ...       ...       ...       ...       ...
# 990  0.068189  0.020155  0.052153  0.015612  0.008540  0.005137  0.043223
# 991  0.063818  0.021654  0.042770  0.016956  0.012039  0.006539  0.034084
# 992  0.078484  0.028307  0.051657  0.024753  0.016637  0.011995  0.033036
# 993  0.079804  0.024340  0.054841  0.023641  0.013874  0.008673  0.032985
# 994  0.098037  0.025834  0.058867  0.021242  0.013265  0.007776  0.037809
#
#             7         8         9  ...       211       212       213  \
# 0    0.011013  0.083127  0.018745  ...  0.019857  0.112252  0.020070
# 1    0.005192  0.113391  0.018215  ...  0.012417  0.174670  0.021423
# 2    0.004991  0.080400  0.015008  ...  0.013921  0.080488  0.013291
# 3    0.005899  0.141468  0.018433  ...  0.011787  0.130650  0.018019
# 4    0.007373  0.087667  0.016506  ...  0.015183  0.119168  0.014663
# ..        ...       ...       ...  ...       ...       ...       ...
# 990  0.010511  0.086169  0.016362  ...  0.021013  0.086872  0.023797
# 991  0.013120  0.058749  0.020486  ...  0.022669  0.084664  0.025686
# 992  0.018311  0.044267  0.023238  ...  0.025893  0.090849  0.029607
# 993  0.014886  0.060582  0.023049  ...  0.024574  0.099127  0.028531
# 994  0.016079  0.063916  0.024518  ...  0.025085  0.133622  0.030514
#
#           214       215       216       217       218       219  220
# 0    0.069725  0.016562  0.073320  0.017913  0.079279  0.021124  0.0
# 1    0.116485  0.015842  0.104936  0.018543  0.127691  0.022997  0.0
# 2    0.048466  0.008639  0.065236  0.011765  0.079929  0.016523  0.0
# 3    0.085559  0.013694  0.128119  0.017048  0.158061  0.021451  0.0
# 4    0.072323  0.010878  0.084324  0.013267  0.097547  0.017690  0.0
# ..        ...       ...       ...       ...       ...       ...  ...
# 990  0.010065  0.005187  0.116975  0.028764  0.070648  0.018068  0.0
# 991  0.012111  0.005112  0.084983  0.024583  0.049400  0.015472  0.0
# 992  0.018677  0.011159  0.080067  0.029623  0.049788  0.021979  0.0
# 993  0.010598  0.007173  0.110171  0.041641  0.060904  0.023557  0.0
# 994  0.012639  0.006191  0.118564  0.035472  0.048184  0.017824  0.0
#
# [995 rows x 221 columns]
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# Categorical data not detected.
# models ['RF', 'XGB']
# scores [0.466218487394958, 0.456750700280112]
# max_mean_cv_validation for no-clustering no-polynomial 0.466218487394958
# models ['RF', 'XGB']
# scores [0.4318487394957984, 0.42952380952380953]
# max_mean_cv_validation for clustering 0.4318487394957984
# models ['RF', 'XGB']
# scores [0.49471988795518207, 0.46865546218487397]
# max_mean_cv_validation for for polynomial 0.49471988795518207
# score_mean_dict {0: 0.466218487394958, 1: 0.4318487394957984, 2: 0.49471988795518207}
# temp_dic {'RF': 0.49471988795518207, 'XGB': 0.46865546218487397}
# selected second:  XGB 0.46865546218487397
# Starting hiper parameters tunning...
# hiper tunning results on RF
#      index name_model validation score  \
# 0       3         RF          0.51598
# 1      13         RF         0.513697
# 2      23         RF         0.513613
# 3      15         RF         0.511275
# 4      25         RF         0.509006
# 5       2         RF         0.507773
# 6       8         RF         0.505518
# 7       7         RF           0.5043
# 8      10         RF         0.501891
# 9      14         RF         0.501821
# 10      6         RF         0.501793
# 11     12         RF         0.498361
# 12      4         RF         0.498151
# 13     29         RF         0.497087
# 14     24         RF         0.496975
# 15     26         RF         0.495854
# 16     27         RF         0.494678
# 17      1         RF         0.493543
# 18     19         RF         0.492423
# 19      9         RF         0.492241
# 20     11         RF         0.491218
# 21     17         RF         0.489958
# 22      0         RF         0.486232
# 23     20         RF         0.482717
# 24     21         RF         0.481583
# 25     16         RF         0.480434
# 26     22         RF         0.479174
# 27     18         RF         0.477731
# 28      5         RF         0.473207
# 29     28         RF         0.460308
#
#                                                params iteration
# 0   {'n_estimators': 38, 'random_state': 42, 'max_...         3
# 1   {'n_estimators': 93, 'random_state': 0, 'max_f...        13
# 2   {'n_estimators': 89, 'random_state': 0, 'max_f...        23
# 3   {'n_estimators': 18, 'random_state': 13, 'max_...        15
# 4   {'n_estimators': 79, 'random_state': 10, 'max_...        25
# 5   {'n_estimators': 55, 'random_state': 10, 'max_...         2
# 6   {'n_estimators': 14, 'random_state': 0, 'max_f...         8
# 7   {'n_estimators': 41, 'random_state': 10, 'max_...         7
# 8   {'n_estimators': 48, 'random_state': 13, 'max_...        10
# 9   {'n_estimators': 11, 'random_state': 13, 'max_...        14
# 10  {'n_estimators': 59, 'random_state': 0, 'max_f...         6
# 11  {'n_estimators': 14, 'random_state': 0, 'max_f...        12
# 12  {'n_estimators': 24, 'random_state': 42, 'max_...         4
# 13  {'n_estimators': 89, 'random_state': 13, 'max_...        29
# 14  {'n_estimators': 7, 'random_state': 0, 'max_fe...        24
# 15  {'n_estimators': 65, 'random_state': 10, 'max_...        26
# 16  {'n_estimators': 72, 'random_state': 0, 'max_f...        27
# 17  {'n_estimators': 59, 'random_state': 13, 'max_...         1
# 18  {'n_estimators': 24, 'random_state': 0, 'max_f...        19
# 19  {'n_estimators': 62, 'random_state': 10, 'max_...         9
# 20  {'n_estimators': 55, 'random_state': 10, 'max_...        11
# 21  {'n_estimators': 7, 'random_state': 10, 'max_f...        17
# 22  {'n_estimators': 1, 'random_state': 10, 'max_f...         0
# 23  {'n_estimators': 38, 'random_state': 42, 'max_...        20
# 24  {'n_estimators': 45, 'random_state': 10, 'max_...        21
# 25  {'n_estimators': 93, 'random_state': 0, 'max_f...        16
# 26  {'n_estimators': 48, 'random_state': 13, 'max_...        22
# 27  {'n_estimators': 14, 'random_state': 13, 'max_...        18
# 28  {'n_estimators': 1, 'random_state': 13, 'max_f...         5
# 29  {'n_estimators': 1, 'random_state': 13, 'max_f...        28
# hiper tunning results on XGB
#      index name_model validation score  \
# 0       7        XGB         0.523375
# 1      26        XGB         0.522073
# 2      19        XGB         0.518473
# 3      22        XGB         0.514972
# 4      14        XGB         0.513852
# 5       0        XGB         0.511443
# 6      25        XGB         0.508011
# 7       8        XGB         0.507871
# 8      23        XGB         0.505504
# 9       5        XGB         0.505378
# 10      2        XGB         0.503193
# 11     17        XGB         0.503137
# 12     29        XGB         0.500756
# 13     10        XGB           0.5007
# 14      1        XGB         0.499664
# 15     21        XGB         0.498389
# 16      4        XGB         0.497325
# 17     13        XGB         0.497199
# 18     27        XGB         0.495966
# 19     24        XGB         0.494916
# 20     12        XGB         0.492507
# 21     18        XGB         0.492423
# 22      6        XGB         0.491317
# 23      9        XGB         0.490098
# 24     11        XGB         0.488824
# 25      3        XGB         0.483025
# 26     20        XGB         0.482997
# 27     15        XGB         0.481891
# 28     28        XGB          0.48049
# 29     16        XGB         0.475952
#
#                                                params iteration
# 0   {'min_child_weight': 1, 'max_depth': 7, 'learn...         7
# 1   {'min_child_weight': 1, 'max_depth': 9, 'learn...        26
# 2   {'min_child_weight': 1, 'max_depth': 10, 'lear...        19
# 3   {'min_child_weight': 1, 'max_depth': 7, 'learn...        22
# 4   {'min_child_weight': 1, 'max_depth': 9, 'learn...        14
# 5   {'min_child_weight': 1, 'max_depth': 9, 'learn...         0
# 6   {'min_child_weight': 1, 'max_depth': 7, 'learn...        25
# 7   {'min_child_weight': 1, 'max_depth': 7, 'learn...         8
# 8   {'min_child_weight': 1, 'max_depth': 7, 'learn...        23
# 9   {'min_child_weight': 1, 'max_depth': 3, 'learn...         5
# 10  {'min_child_weight': 1, 'max_depth': 10, 'lear...         2
# 11  {'min_child_weight': 1, 'max_depth': 9, 'learn...        17
# 12  {'min_child_weight': 1, 'max_depth': 7, 'learn...        29
# 13  {'min_child_weight': 1, 'max_depth': 10, 'lear...        10
# 14  {'min_child_weight': 1, 'max_depth': 10, 'lear...         1
# 15  {'min_child_weight': 1, 'max_depth': 9, 'learn...        21
# 16  {'min_child_weight': 1, 'max_depth': 9, 'learn...         4
# 17  {'min_child_weight': 1, 'max_depth': 9, 'learn...        13
# 18  {'min_child_weight': 1, 'max_depth': 7, 'learn...        27
# 19  {'min_child_weight': 1, 'max_depth': 10, 'lear...        24
# 20  {'min_child_weight': 1, 'max_depth': 10, 'lear...        12
# 21  {'min_child_weight': 1, 'max_depth': 9, 'learn...        18
# 22  {'min_child_weight': 1, 'max_depth': 7, 'learn...         6
# 23  {'min_child_weight': 1, 'max_depth': 9, 'learn...         9
# 24  {'min_child_weight': 1, 'max_depth': 3, 'learn...        11
# 25  {'min_child_weight': 1, 'max_depth': 7, 'learn...         3
# 26  {'min_child_weight': 1, 'max_depth': 7, 'learn...        20
# 27  {'min_child_weight': 1, 'max_depth': 10, 'lear...        15
# 28  {'min_child_weight': 1, 'max_depth': 3, 'learn...        28
# 29  {'min_child_weight': 1, 'max_depth': 7, 'learn...        16
# before walking around hyperparameters
# RF 0.5159803921568628
# XGB 0.523375350140056
# first futher op
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 10
# new score: 0.5276050420168067
# old score 0.5159803921568628
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 80
# new score: 0.5276050420168067
# old score 0.5276050420168067
# walking around  min_samples_split
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_split 5
# new score: 0.5276050420168067
# old score 0.5276050420168067
# walking around  min_samples_leaf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_leaf 1
# new score: 0.5276050420168067
# old score 0.5276050420168067
# walking around  bootstrap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters bootstrap 0
# new score: 0.5276050420168067
# old score 0.5276050420168067
# second futher op
# walking around  min_child_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_child_weight 1
# new score: 0.523375350140056
# old score 0.523375350140056
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 7
# new score: 0.523375350140056
# old score 0.523375350140056
# walking around  learning_rate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters learning_rate 0.03375
# new score: 0.5114285714285716
# old score 0.523375350140056
# walking around  reg_alpha
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_alpha 1.5749999999999997
# new score: 0.5126470588235295
# old score 0.523375350140056
# walking around  reg_lambda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_lambda 4.050000000000001
# new score: 0.5197619047619046
# old score 0.523375350140056
# walking around  gamma
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters gamma 0.0225
# new score: 0.5244817927170868
# old score 0.523375350140056
# walking around  subsample
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters subsample 0.375
# new score: 0.5043417366946779
# old score 0.5244817927170868
# walking around  colsample_bytree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters colsample_bytree 0.3375
# new score: 0.506624649859944
# old score 0.5244817927170868
# walking around  scale_pos_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters scale_pos_weight 1
# new score: 0.5244817927170868
# old score 0.5244817927170868
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 42
# new score: 0.5280392156862745
# old score 0.5244817927170868
# calculating candidates on test set:
# 1. best tunned model based on cv validation
# 2. best tunned model based on minimun std
# 3. first model (with default parameters)
# 4. second model (with default parameters)
# expected_score_1,expected_score_2 0.5733333333333334 0.56
# expected_score_3,expected_score_4 0.5533333333333333 0.5466666666666666
# results_on_test_dict {1: 0.5733333333333334, 2: 0.56, 3: 0.5533333333333333, 4: 0.5466666666666666}
# selected_key 1
# l [{'n_estimators': 10, 'random_state': 42, 'max_features': 'auto', 'max_depth': 90, 'min_samples_split': 5, 'min_samples_leaf': 1, 'bootstrap': False}, 1.0, 0.5733333333333334, 'RF', 1.1624649859943936]
# saving scaler at /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_alpha_beta/eeg_alpha_beta_scaler.file
# Raw accuracy 0.47998628022637624
# ajusted_acc 0.4880647911338448
# selected_model: RF
# selected parameters: {'n_estimators': 10, 'random_state': 42, 'max_features': 'auto', 'max_depth': 90, 'min_samples_split': 5, 'min_samples_leaf': 1, 'bootstrap': False}
# score on test set of data: 0.5733333333333334
# Do not forget to see your report in: /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_alpha_beta
# --- 1020.5383067131042 seconds ---
# EEG 0.5733333333333334

# %%
experiment="delta"

run_experiment(experiment)
# Out:
# categorical_columns Index([], dtype='object')
#             0         1         2         3         4         5         6  \
# 0    0.710053  0.673089  0.896782  0.894461  0.803025  0.905243  0.851430
# 1    0.706104  0.699184  0.926069  0.924477  0.738980  0.919729  0.874682
# 2    0.774367  0.787049  0.919943  0.918186  0.774419  0.900345  0.899505
# 3    0.673525  0.638863  0.939211  0.936929  0.718696  0.949319  0.893448
# 4    0.755188  0.732251  0.925613  0.923918  0.778855  0.922397  0.877906
# ..        ...       ...       ...       ...       ...       ...       ...
# 990  0.768916  0.846233  0.965749  0.899205  0.807408  0.726484  0.845351
# 991  0.734641  0.810500  0.951981  0.869593  0.772897  0.771080  0.873558
# 992  0.710368  0.778035  0.932531  0.862491  0.801285  0.780717  0.848569
# 993  0.751620  0.817576  0.941502  0.886195  0.804049  0.775063  0.879014
# 994  0.744385  0.828992  0.948033  0.888940  0.815302  0.795131  0.894342
#
#             7         8         9  ...       101       102       103  \
# 0    0.776157  0.697889  0.902589  ...  0.774622  0.788456  0.830294
# 1    0.775566  0.754797  0.933571  ...  0.724117  0.651529  0.788593
# 2    0.824268  0.831262  0.932374  ...  0.832532  0.808870  0.828406
# 3    0.697747  0.623129  0.944686  ...  0.777034  0.711537  0.817681
# 4    0.831979  0.781081  0.931823  ...  0.771209  0.778099  0.816902
# ..        ...       ...       ...  ...       ...       ...       ...
# 990  0.775649  0.803043  0.951389  ...  0.954744  0.769338  0.855843
# 991  0.792669  0.771981  0.946248  ...  0.945367  0.748409  0.824006
# 992  0.764968  0.761452  0.925305  ...  0.927876  0.689381  0.793642
# 993  0.813823  0.778257  0.929710  ...  0.946810  0.753933  0.828135
# 994  0.808093  0.793333  0.944341  ...  0.943729  0.768249  0.848453
#
#           104       105       106       107       108       109  110
# 0    0.831809  0.763104  0.724282  0.794526  0.814169  0.794942  0.0
# 1    0.805144  0.771237  0.645808  0.753555  0.783362  0.725556  0.0
# 2    0.822836  0.768218  0.806882  0.866399  0.839726  0.779125  0.0
# 3    0.814847  0.797649  0.691532  0.804588  0.748032  0.686124  0.0
# 4    0.811028  0.731461  0.738376  0.828966  0.802972  0.757020  0.0
# ..        ...       ...       ...       ...       ...       ...  ...
# 990  0.630448  0.739897  0.694847  0.965886  0.636125  0.763023  0.0
# 991  0.668552  0.708509  0.655127  0.959453  0.664630  0.796511  0.0
# 992  0.716821  0.734602  0.679433  0.938932  0.678932  0.773936  0.0
# 993  0.627285  0.727498  0.680772  0.952821  0.629771  0.775656  0.0
# 994  0.620519  0.733728  0.666772  0.950227  0.619517  0.801778  0.0
#
# [995 rows x 111 columns]
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# selected from_inattentive:  ['NDARHN931CJV', 'NDARBJ482HJL', 'NDARJZ274PRQ', 'NDARVP953BBF', 'NDARHC462NGR', 'NDARBF176LPM', 'NDARHG294AFG']
# selected from_healthy:  ['NDARLU606ZDD', 'NDARTH473LF8', 'NDAREW976FNL', 'NDARHJ945PV0', 'NDARRV638MJV', 'NDAREW201WD9', 'NDARGT682ZWN', 'NDARHV527DNK', 'NDARWA544RDT', 'NDARLJ886BFK', 'NDARVE724GEF', 'NDARTF566PYH', 'NDAREX065KJU', 'NDARAU447JZH', 'NDARLX816JUZ']
# selected from_hyperactive:  ['NDARPW577WJ7', 'NDARJE686DJL', 'NDARYL124VM6']
# selected from_combined:  ['NDARKP815KPZ', 'NDARUM991EE8', 'NDARRF897HB5', 'NDARWX338NDL', 'NDARZF949WTW']
# total valid: 30
# Categorical data not detected.
# models ['RF', 'XGB']
# scores [0.4992997198879552, 0.4733893557422969]
# max_mean_cv_validation for no-clustering no-polynomial 0.4992997198879552
# models ['RF', 'XGB']
# scores [0.46956582633053223, 0.4922689075630252]
# max_mean_cv_validation for clustering 0.4922689075630252
# models ['RF', 'XGB']
# scores [0.4741036414565826, 0.4932072829131653]
# max_mean_cv_validation for for polynomial 0.4932072829131653
# score_mean_dict {0: 0.4992997198879552, 1: 0.4922689075630252, 2: 0.4932072829131653}
# temp_dic {'RF': 0.4992997198879552, 'XGB': 0.4733893557422969}
# selected second:  XGB 0.4733893557422969
# Starting hiper parameters tunning...
# hiper tunning results on RF
#      index name_model validation score  \
# 0       3         RF         0.527815
# 1      21         RF         0.522829
# 2       5         RF         0.513585
# 3       6         RF          0.51119
# 4      24         RF         0.507619
# 5       7         RF         0.506331
# 6       2         RF         0.504048
# 7      11         RF         0.503179
# 8      17         RF         0.501933
# 9      18         RF         0.501765
# 10     13         RF         0.499314
# 11     22         RF         0.499258
# 12     14         RF         0.498249
# 13     16         RF         0.497017
# 14     26         RF         0.495896
# 15     19         RF         0.495154
# 16     20         RF         0.493515
# 17     23         RF         0.493487
# 18     28         RF         0.493473
# 19     29         RF          0.48986
# 20      0         RF         0.489734
# 21     10         RF          0.48888
# 22      1         RF         0.485238
# 23     25         RF         0.482885
# 24      8         RF         0.482675
# 25     27         RF         0.479132
# 26      4         RF         0.470896
# 27      9         RF         0.468179
# 28     12         RF         0.467507
# 29     15         RF         0.466303
#
#                                                params iteration
# 0   {'n_estimators': 14, 'random_state': 10, 'max_...         3
# 1   {'n_estimators': 4, 'random_state': 13, 'max_f...        21
# 2   {'n_estimators': 21, 'random_state': 10, 'max_...         5
# 3   {'n_estimators': 48, 'random_state': 10, 'max_...         6
# 4   {'n_estimators': 96, 'random_state': 0, 'max_f...        24
# 5   {'n_estimators': 1, 'random_state': 13, 'max_f...         7
# 6   {'n_estimators': 21, 'random_state': 42, 'max_...         2
# 7   {'n_estimators': 35, 'random_state': 42, 'max_...        11
# 8   {'n_estimators': 93, 'random_state': 10, 'max_...        17
# 9   {'n_estimators': 41, 'random_state': 10, 'max_...        18
# 10  {'n_estimators': 59, 'random_state': 13, 'max_...        13
# 11  {'n_estimators': 11, 'random_state': 13, 'max_...        22
# 12  {'n_estimators': 21, 'random_state': 10, 'max_...        14
# 13  {'n_estimators': 93, 'random_state': 13, 'max_...        16
# 14  {'n_estimators': 100, 'random_state': 0, 'max_...        26
# 15  {'n_estimators': 14, 'random_state': 10, 'max_...        19
# 16  {'n_estimators': 35, 'random_state': 0, 'max_f...        20
# 17  {'n_estimators': 59, 'random_state': 42, 'max_...        23
# 18  {'n_estimators': 65, 'random_state': 13, 'max_...        28
# 19  {'n_estimators': 79, 'random_state': 10, 'max_...        29
# 20  {'n_estimators': 65, 'random_state': 13, 'max_...         0
# 21  {'n_estimators': 38, 'random_state': 13, 'max_...        10
# 22  {'n_estimators': 52, 'random_state': 0, 'max_f...         1
# 23  {'n_estimators': 52, 'random_state': 13, 'max_...        25
# 24  {'n_estimators': 24, 'random_state': 13, 'max_...         8
# 25  {'n_estimators': 62, 'random_state': 10, 'max_...        27
# 26  {'n_estimators': 11, 'random_state': 42, 'max_...         4
# 27  {'n_estimators': 1, 'random_state': 42, 'max_f...         9
# 28  {'n_estimators': 100, 'random_state': 42, 'max...        12
# 29  {'n_estimators': 72, 'random_state': 13, 'max_...        15
# hiper tunning results on XGB
#      index name_model validation score  \
# 0      20        XGB         0.511218
# 1       2        XGB         0.510028
# 2      12        XGB         0.500602
# 3      10        XGB         0.500532
# 4      19        XGB         0.498207
# 5       3        XGB         0.494734
# 6      15        XGB         0.494636
# 7       6        XGB         0.492325
# 8      29        XGB         0.491134
# 9      28        XGB         0.486387
# 10      8        XGB         0.486289
# 11     23        XGB         0.480378
# 12      7        XGB         0.479202
# 13     27        XGB         0.477955
# 14     22        XGB         0.474426
# 15     14        XGB         0.473487
# 16      0        XGB         0.473389
# 17     26        XGB         0.471092
# 18      1        XGB         0.471036
# 19     18        XGB         0.470994
# 20     11        XGB          0.47091
# 21     21        XGB         0.470896
# 22      5        XGB         0.468571
# 23     13        XGB         0.466162
# 24     24        XGB         0.459034
# 25      4        XGB         0.456877
# 26     16        XGB         0.455742
# 27     25        XGB         0.454454
# 28     17        XGB         0.447353
# 29      9        XGB         0.444958
#
#                                                params iteration
# 0   {'min_child_weight': 1, 'max_depth': 3, 'learn...        20
# 1   {'min_child_weight': 1, 'max_depth': 9, 'learn...         2
# 2   {'min_child_weight': 1, 'max_depth': 10, 'lear...        12
# 3   {'min_child_weight': 1, 'max_depth': 3, 'learn...        10
# 4   {'min_child_weight': 1, 'max_depth': 7, 'learn...        19
# 5   {'min_child_weight': 1, 'max_depth': 3, 'learn...         3
# 6   {'min_child_weight': 1, 'max_depth': 7, 'learn...        15
# 7   {'min_child_weight': 1, 'max_depth': 3, 'learn...         6
# 8   {'min_child_weight': 1, 'max_depth': 3, 'learn...        29
# 9   {'min_child_weight': 1, 'max_depth': 3, 'learn...        28
# 10  {'min_child_weight': 1, 'max_depth': 3, 'learn...         8
# 11  {'min_child_weight': 1, 'max_depth': 10, 'lear...        23
# 12  {'min_child_weight': 1, 'max_depth': 9, 'learn...         7
# 13  {'min_child_weight': 1, 'max_depth': 10, 'lear...        27
# 14  {'min_child_weight': 1, 'max_depth': 9, 'learn...        22
# 15  {'min_child_weight': 1, 'max_depth': 9, 'learn...        14
# 16  {'min_child_weight': 1, 'max_depth': 10, 'lear...         0
# 17  {'min_child_weight': 1, 'max_depth': 3, 'learn...        26
# 18  {'min_child_weight': 1, 'max_depth': 10, 'lear...         1
# 19  {'min_child_weight': 1, 'max_depth': 3, 'learn...        18
# 20  {'min_child_weight': 1, 'max_depth': 3, 'learn...        11
# 21  {'min_child_weight': 1, 'max_depth': 9, 'learn...        21
# 22  {'min_child_weight': 1, 'max_depth': 7, 'learn...         5
# 23  {'min_child_weight': 1, 'max_depth': 10, 'lear...        13
# 24  {'min_child_weight': 1, 'max_depth': 10, 'lear...        24
# 25  {'min_child_weight': 1, 'max_depth': 10, 'lear...         4
# 26  {'min_child_weight': 1, 'max_depth': 10, 'lear...        16
# 27  {'min_child_weight': 1, 'max_depth': 9, 'learn...        25
# 28  {'min_child_weight': 1, 'max_depth': 7, 'learn...        17
# 29  {'min_child_weight': 1, 'max_depth': 7, 'learn...         9
# before walking around hyperparameters
# RF 0.5278151260504202
# XGB 0.511218487394958
# first futher op
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 2
# new score: 0.53890756302521
# old score 0.5278151260504202
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 60
# new score: 0.53890756302521
# old score 0.53890756302521
# walking around  min_samples_split
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_split 2
# new score: 0.5752380952380951
# old score 0.53890756302521
# walking around  min_samples_leaf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_samples_leaf 2
# new score: 0.5752380952380951
# old score 0.5752380952380951
# walking around  bootstrap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters bootstrap 0
# new score: 0.5752380952380951
# old score 0.5752380952380951
# second futher op
# walking around  min_child_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters min_child_weight 1
# new score: 0.511218487394958
# old score 0.511218487394958
# walking around  max_depth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters max_depth 6
# new score: 0.5124509803921569
# old score 0.511218487394958
# walking around  learning_rate
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters learning_rate 1.4625
# new score: 0.518375350140056
# old score 0.5124509803921569
# walking around  reg_alpha
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_alpha 0.09
# new score: 0.5102801120448179
# old score 0.518375350140056
# walking around  reg_lambda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters reg_lambda 0.0
# new score: 0.512296918767507
# old score 0.518375350140056
# walking around  gamma
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters gamma 0.00375
# new score: 0.514873949579832
# old score 0.518375350140056
# walking around  subsample
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters subsample 0.0
# new score: 0.5
# old score 0.518375350140056
# walking around  colsample_bytree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters colsample_bytree 0.0
# new score: 0.5548879551820729
# old score 0.518375350140056
# walking around  scale_pos_weight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters scale_pos_weight 9
# new score: 0.5578291316526611
# old score 0.5548879551820729
# walking around  n_estimators
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# candidate update hiperparameters n_estimators 168
# new score: 0.5625490196078431
# old score 0.5578291316526611
# calculating candidates on test set:
# 1. best tunned model based on cv validation
# 2. best tunned model based on minimun std
# 3. first model (with default parameters)
# 4. second model (with default parameters)
# expected_score_1,expected_score_2 0.45333333333333337 0.5
# expected_score_3,expected_score_4 0.5933333333333334 0.6133333333333333
# results_on_test_dict {1: 0.45333333333333337, 2: 0.5, 3: 0.5933333333333334, 4: 0.6133333333333333}
# selected_key 4
# l [None, 0.9928571428571429, 0.6133333333333333, 'XGB', None]
# saving scaler at /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_delta/eeg_delta_scaler.file
# Raw accuracy 0.5900360144057624
# ajusted_acc 0.6278772378516624
# selected_model: XGB
# selected parameters: None
# score on test set of data: 0.6133333333333333
# Do not forget to see your report in: /home/gari/Desktop/master_tesis_v2/MLDiagnosisTool/eeg_delta
# --- 732.3478791713715 seconds ---
# EEG 0.6133333333333333

# %%
#experiment="entropy"

#run_experiment(experiment)

# %%
#experiment="entropy_delta_theta"

#run_experiment(experiment)
